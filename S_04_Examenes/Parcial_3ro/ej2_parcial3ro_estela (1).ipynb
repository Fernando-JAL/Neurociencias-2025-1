# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import scipy.io
from matplotlib import animation
import sys

# %%
sys.path.append(r"C:\Users\estel\OneDrive\Escritorio\NEUROCIENCIAS\QUINTO SEMESTRE\MODELOS\Neurociencias-2025-1\S_03_Clases\Ejercicios")
import animation2_1
import animation2_2

# %%
# Analice el código en los archivos animation2_1 y animation2_2
print(dir(animation2_1)) # ojazo al contenido de animation2_1
print(dir(animation2_2)) # ojazo al contenido de animation2_2
# Out:
# ['G', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'animation', 'ax', 'degrees', 'edge', 'edges', 'fig', 'mpl', 'nodes', 'np', 'nx', 'plt', 'random_sizes', 'x', 'y', 'z']
# ['G', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'ani', 'animate', 'animation', 'ax', 'edges', 'fig', 'init', 'nodes', 'np', 'nx', 'plt', 'x', 'y', 'z']

# %%
print("contenido de nodes en 2_1:", animation2_1.nodes) # ver contenido de nodes en 2_1
print("contenido de edges en 2_1:", animation2_1.edges) # ver contenido de aristas en 2_1
# Out:
# contenido de nodes en 2_1: [[-1.         -0.13278077 -0.0675157 ]
#  [-0.74535599  0.5418651   0.11842486]
#  [-0.33333333  0.81169596 -0.39102575]
#  [-0.33333333  0.30381473 -0.89182412]
#  [ 0.33333333  0.14755841 -0.91126968]
#  [ 0.74535599  0.55886793 -0.42248934]
#  [ 0.33333333  0.96932751 -0.10096091]
#  [ 0.33333333  0.79691831  0.58775964]
#  [-0.33333333  0.53273201  0.7233475 ]
#  [-0.33333333 -0.14755841  0.91126968]
#  [-0.74535599 -0.55886793  0.42248934]
#  [-0.33333333 -0.96932751  0.10096091]
#  [ 0.33333333 -0.81169596  0.39102575]
#  [ 0.33333333 -0.30381473  0.89182412]
#  [ 0.74535599  0.27990399  0.69188391]
#  [ 1.          0.13278077  0.0675157 ]
#  [ 0.74535599 -0.5418651  -0.11842486]
#  [ 0.33333333 -0.53273201 -0.7233475 ]
#  [-0.33333333 -0.79691831 -0.58775964]
#  [-0.74535599 -0.27990399 -0.69188391]]
# contenido de edges en 2_1: [[[-1.         -0.13278077 -0.0675157 ]
#   [-0.74535599  0.5418651   0.11842486]]
#
# ...

# %%
print("contenido de nodes en 2_2:", animation2_2.nodes) # ver contenido de nodes en 2_2
print("contenido de edges en 2_2:", animation2_2.edges) # ver contenido de aristas en 2_2
# Out:
# contenido de nodes en 2_1: [[-1.         -0.13278077 -0.0675157 ]
#  [-0.74535599  0.5418651   0.11842486]
#  [-0.33333333  0.81169596 -0.39102575]
#  [-0.33333333  0.30381473 -0.89182412]
#  [ 0.33333333  0.14755841 -0.91126968]
#  [ 0.74535599  0.55886793 -0.42248934]
#  [ 0.33333333  0.96932751 -0.10096091]
#  [ 0.33333333  0.79691831  0.58775964]
#  [-0.33333333  0.53273201  0.7233475 ]
#  [-0.33333333 -0.14755841  0.91126968]
#  [-0.74535599 -0.55886793  0.42248934]
#  [-0.33333333 -0.96932751  0.10096091]
#  [ 0.33333333 -0.81169596  0.39102575]
#  [ 0.33333333 -0.30381473  0.89182412]
#  [ 0.74535599  0.27990399  0.69188391]
#  [ 1.          0.13278077  0.0675157 ]
#  [ 0.74535599 -0.5418651  -0.11842486]
#  [ 0.33333333 -0.53273201 -0.7233475 ]
#  [-0.33333333 -0.79691831 -0.58775964]
#  [-0.74535599 -0.27990399 -0.69188391]]
# contenido de edges en 2_1: [[[-1.         -0.13278077 -0.0675157 ]
#   [-0.74535599  0.5418651   0.11842486]]
#
# ...

# %%
# ¿qué forma tiene el grafo de animation2_1?  
G1 = animation2_1.G
G1
print("G1 tiene forma: ")

# ¿cuántos nodos tiene el grafo? ¿con qué comando se descubre el número de nodos?
num_nodes2_1 = G1.number_of_nodes() # número de nodos, con comando number_of_nodes
print("el número de nodos de G1: ", num_nodes2_1)

# ¿cuántas aristas tiene el grafo? ¿con qué comando se descubre el número de aristas?
num_edges2_1 = G1.number_of_edges() # número de aristas, con comando number_of_edges
print("el número de aristas de G1: ", num_edges2_1)
plt.figure(figsize = (8, 8))
nx.draw(G2, with_labels = True, node_size = 300, node_color = "purple")
# Out:
# el número de nodos:  20
# el número de aristas:  30

# %%
# ¿qué forma tiene el grafo de animation2_2? R: 
G2 = animation2_2.G
G2
print("G2 tiene forma: ")
# ¿cuántos nodos tiene el grafo?
num_nodes2_2 = G2.number_of_nodes() # número de nodos
print("el número de nodos de G2 es : ", num_nodes2_2)
# ¿cuántas aristas tiene el grafo?
num_edges2_2 = G2.number_of_edges() # número de aristas
print("el número de aristas de G2 es: ", num_edges2_2)
plt.figure(figsize = (8, 8))
nx.draw(G2, with_labels = True, node_size = 300, node_color = "cyan")
# Out:
# el número de nodos:  20
# el número de aristas:  30

# %%
# ¿qué hace el código G.degree()?
grado_nodosG1 = G1.degree()
grado_nodosG2 = G2.degree()
print("el método G.degree permite obtener el grado de los nodos en un grafo: ")
print("el grado de G1 es: ", grado_nodosG1)
print("el grado de G2 es: ", grado_nodosG2)
# Out:
# el método G.degree permite obtener el grado de los nodos en un grafo:
# el grado de G1 es:  [(0, 3), (1, 3), (2, 3), (3, 3), (4, 3), (5, 3), (6, 3), (7, 3), (8, 3), (9, 3), (10, 3), (11, 3), (12, 3), (13, 3), (14, 3), (15, 3), (16, 3), (17, 3), (18, 3), (19, 3)]
# el grado de G2 es:  [(0, 3), (1, 3), (2, 3), (3, 3), (4, 3), (5, 3), (6, 3), (7, 3), (8, 3), (9, 3), (10, 3), (11, 3), (12, 3), (13, 3), (14, 3), (15, 3), (16, 3), (17, 3), (18, 3), (19, 3)]

# %%
# ¿cuál es el número MÁXIMO de aristas en el grafo?
# podemos sacar el número máximo de aristas porque es un grafo no dirigido
# hacemos uso de la fórmula n(n-1)/2:
max_aristasG1 = num_nodes2_1 * (num_nodes2_1 -1) // 2
print("el número máximo de aristas para G1 es: ", max_aristasG1)
max_aristasG2 = num_nodes2_2 * (num_nodes2_2 -1) // 2
print("el número máximo de aristas para G2 es: ", max_aristasG2)
# Out:
# el número máximo de aristas para G1 es:  190
# el número máximo de aristas para G2 es:  190

# %%
# ¿cuál es la diferencia entre animation2_1 y animation 2_2
# R: ambos grafos tienen características iguales (número de nodos, número de aristas, grado de nodos)
# R: las aristas de cada grafo tienen distribución espacial diferente 
# R: y sus representaciones visuales varían.
