# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import networkx as nx
import scipy.io
from matplotlib import cm  # Import colormap 
from matplotlib.animation import FuncAnimation

# %%
"""

Analice el código en los archivos animation2_1 y animation2_2 y conteste lo siguiente:

¿Qué forma tiene el grafo?
¿Cuántos nodos tiene el grafo?, ¿con qué comando descubres el número de nodos?
¿Cuántas aristas tiene el grafo?, ¿con qué comando descubres el número de nodos?
¿Qué hace el código G.degree()?
¿Cuál es el número máximo de aristas en el grafo?
¿Cuál es la diferencia entre animation2_1 y animation2_2?

"""
# Out:
# '\n\nAnalice el código en los archivos animation2_1 y animation2_2 y conteste lo siguiente:\n\n¿Qué forma tiene el grafo?\n¿Cuántos nodos tiene el grafo?, ¿con qué comando descubres el número de nodos?\n¿Cuántas aristas tiene el grafo?, ¿con qué comando descubres el número de nodos?\n¿Qué hace el código G.degree()?\n¿Cuál es el número máximo de aristas en el grafo?\n¿Cuál es la diferencia entre animation2_1 y animation2_2?\n\n'

# %%
"""
animation2_1.py:

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib as mpl

# Se carga el grado del dodecaedro
G = nx.dodecahedral_graph()
# Se definen las coordenadas de cada nodo
x = np.array([-1.        , -0.74535599, -0.33333333, -0.33333333,  0.33333333, 0.74535599,  0.33333333,  0.33333333, -0.33333333, -0.33333333, -0.74535599, -0.33333333,  0.33333333,  0.33333333,  0.74535599, 1.        ,  0.74535599,  0.33333333, -0.33333333, -0.74535599])
y = np.array([-0.13278077,  0.5418651 ,  0.81169596,  0.30381473,  0.14755841, 0.55886793,  0.96932751,  0.79691831,  0.53273201, -0.14755841, -0.55886793, -0.96932751, -0.81169596, -0.30381473,  0.27990399, 0.13278077, -0.5418651 , -0.53273201, -0.79691831, -0.27990399])
z = np.array([-0.0675157 ,  0.11842486, -0.39102575, -0.89182412, -0.91126968, -0.42248934, -0.10096091,  0.58775964,  0.7233475 ,  0.91126968, 0.42248934,  0.10096091,  0.39102575,  0.89182412,  0.69188391, 0.0675157 , -0.11842486, -0.7233475 , -0.58775964, -0.69188391])

# Se crean los nodos y las aristas acorde al grafo
nodes = np.array([[i, j, k] for i, j, k in zip(x, y, z)])
edges = np.array([(nodes[u], nodes[v]) for u, v in G.edges()])

random_sizes = np.random.randint(50, 500, size=len(nodes))


# Se grafica
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111, projection="3d")

# Se grafican los nodos
ax.scatter(*nodes.T)  # Equivalente a ax.scatter(x, y, z)
# Se grafican las aristas
for edge in edges:
    ax.plot(*edge.T)

plt.show()

# Calcula el grado de cada nodo y lo convierte a un diccionario
degrees = dict(G.degree())
# Grafica el histograma
plt.hist(degrees.values())
plt.show()
"""
# Out:
# '\nanimation2_1.py:\n\nimport numpy as np\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom matplotlib import animation\nimport matplotlib as mpl\n\n# Se carga el grado del dodecaedro\nG = nx.dodecahedral_graph()\n# Se definen las coordenadas de cada nodo\nx = np.array([-1.        , -0.74535599, -0.33333333, -0.33333333,  0.33333333, 0.74535599,  0.33333333,  0.33333333, -0.33333333, -0.33333333, -0.74535599, -0.33333333,  0.33333333,  0.33333333,  0.74535599, 1.        ,  0.74535599,  0.33333333, -0.33333333, -0.74535599])\ny = np.array([-0.13278077,  0.5418651 ,  0.81169596,  0.30381473,  0.14755841, 0.55886793,  0.96932751,  0.79691831,  0.53273201, -0.14755841, -0.55886793, -0.96932751, -0.81169596, -0.30381473,  0.27990399, 0.13278077, -0.5418651 , -0.53273201, -0.79691831, -0.27990399])\nz = np.array([-0.0675157 ,  0.11842486, -0.39102575, -0.89182412, -0.91126968, -0.42248934, -0.10096091,  0.58775964,  0.7233475 ,  0.91126968, 0.42248934,  0.10096091,  0.39102575,  0.89182412,  0.69188391, 0.0675157 , -0.11842486, -0.7233475 , -0.58775964, -0.69188391])\n\n# Se crean los nodos y las aristas acorde al grafo\nnodes = np.array([[i, j, k] for i, j, k in zip(x, y, z)])\nedges = np.array([(nodes[u], nodes[v]) for u, v in G.edges()])\n\nrandom_sizes = np.random.randint(50, 500, size=len(nodes))\n\n\n# Se grafica\nfig = plt.figure(figsize = (15, 15))\nax = fig.add_subplot(111, projection="3d")\n\n# Se grafican los nodos\nax.scatter(*nodes.T)  # Equivalente a ax.scatter(x, y, z)\n# Se grafican las aristas\nfor edge in edges:\n    ax.plot(*edge.T)\n\nplt.show()\n\n# Calcula el grado de cada nodo y lo convierte a un diccionario\ndegrees = dict(G.degree())\n# Grafica el histograma\nplt.hist(degrees.values())\nplt.show()\n'

# %%
"""
animation2_2.py:

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib import animation

# Se carga el grado del dodecaedro
G = nx.dodecahedral_graph()
# Se definen las coordenadas de cada nodo
x = np.array([-1.        , -0.74535599, -0.33333333, -0.33333333,  0.33333333, 0.74535599,  0.33333333,  0.33333333, -0.33333333, -0.33333333, -0.74535599, -0.33333333,  0.33333333,  0.33333333,  0.74535599, 1.        ,  0.74535599,  0.33333333, -0.33333333, -0.74535599])
y = np.array([-0.13278077,  0.5418651 ,  0.81169596,  0.30381473,  0.14755841, 0.55886793,  0.96932751,  0.79691831,  0.53273201, -0.14755841, -0.55886793, -0.96932751, -0.81169596, -0.30381473,  0.27990399, 0.13278077, -0.5418651 , -0.53273201, -0.79691831, -0.27990399])
z = np.array([-0.0675157 ,  0.11842486, -0.39102575, -0.89182412, -0.91126968, -0.42248934, -0.10096091,  0.58775964,  0.7233475 ,  0.91126968, 0.42248934,  0.10096091,  0.39102575,  0.89182412,  0.69188391, 0.0675157 , -0.11842486, -0.7233475 , -0.58775964, -0.69188391])

# Se crean los nodos y las aristas acorde al grafo
nodes = np.array([[i, j, k] for i, j, k in zip(x, y, z)])
edges = np.array([(nodes[u], nodes[v]) for u, v in G.edges()])

# Se grafica
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111, projection="3d")

def init():
    # Se grafican los nodos
    ax.scatter(*nodes.T)  # Equivalente a ax.scatter(x, y, z)
    # Se grafican las aristas
    for edge in edges:
        ax.plot(*edge.T)

    return fig,

def animate(i):
    ax.view_init(elev=20, azim=i*4)
    return fig,

ani = animation.FuncAnimation(fig, animate, init_func=init, frames=90, interval=200, blit=False)
plt.show()

"""
# Out:
# '\nanimation2_2.py:\n\nimport numpy as np\nimport networkx as nx\nimport matplotlib.pyplot as plt\nfrom matplotlib import animation\n\n# Se carga el grado del dodecaedro\nG = nx.dodecahedral_graph()\n# Se definen las coordenadas de cada nodo\nx = np.array([-1.        , -0.74535599, -0.33333333, -0.33333333,  0.33333333, 0.74535599,  0.33333333,  0.33333333, -0.33333333, -0.33333333, -0.74535599, -0.33333333,  0.33333333,  0.33333333,  0.74535599, 1.        ,  0.74535599,  0.33333333, -0.33333333, -0.74535599])\ny = np.array([-0.13278077,  0.5418651 ,  0.81169596,  0.30381473,  0.14755841, 0.55886793,  0.96932751,  0.79691831,  0.53273201, -0.14755841, -0.55886793, -0.96932751, -0.81169596, -0.30381473,  0.27990399, 0.13278077, -0.5418651 , -0.53273201, -0.79691831, -0.27990399])\nz = np.array([-0.0675157 ,  0.11842486, -0.39102575, -0.89182412, -0.91126968, -0.42248934, -0.10096091,  0.58775964,  0.7233475 ,  0.91126968, 0.42248934,  0.10096091,  0.39102575,  0.89182412,  0.69188391, 0.0675157 , -0.11842486, -0.7233475 , -0.58775964, -0.69188391])\n\n# Se crean los nodos y las aristas acorde al grafo\nnodes = np.array([[i, j, k] for i, j, k in zip(x, y, z)])\nedges = np.array([(nodes[u], nodes[v]) for u, v in G.edges()])\n\n# Se grafica\nfig = plt.figure(figsize = (15, 15))\nax = fig.add_subplot(111, projection="3d")\n\ndef init():\n    # Se grafican los nodos\n    ax.scatter(*nodes.T)  # Equivalente a ax.scatter(x, y, z)\n    # Se grafican las aristas\n    for edge in edges:\n        ax.plot(*edge.T)\n\n    return fig,\n\ndef animate(i):\n    ax.view_init(elev=20, azim=i*4)\n    return fig,\n\nani = animation.FuncAnimation(fig, animate, init_func=init, frames=90, interval=200, blit=False)\nplt.show()\n\n'

# %%
"""
¿Qué forma tiene el grafo?

Está forma.

"""

# Se carga el grado del dodecaedro
G = nx.dodecahedral_graph()
# Se definen las coordenadas de cada nodo
x = np.array([-1.        , -0.74535599, -0.33333333, -0.33333333,  0.33333333, 0.74535599,  0.33333333,  0.33333333, -0.33333333, -0.33333333, -0.74535599, -0.33333333,  0.33333333,  0.33333333,  0.74535599, 1.        ,  0.74535599,  0.33333333, -0.33333333, -0.74535599])
y = np.array([-0.13278077,  0.5418651 ,  0.81169596,  0.30381473,  0.14755841, 0.55886793,  0.96932751,  0.79691831,  0.53273201, -0.14755841, -0.55886793, -0.96932751, -0.81169596, -0.30381473,  0.27990399, 0.13278077, -0.5418651 , -0.53273201, -0.79691831, -0.27990399])
z = np.array([-0.0675157 ,  0.11842486, -0.39102575, -0.89182412, -0.91126968, -0.42248934, -0.10096091,  0.58775964,  0.7233475 ,  0.91126968, 0.42248934,  0.10096091,  0.39102575,  0.89182412,  0.69188391, 0.0675157 , -0.11842486, -0.7233475 , -0.58775964, -0.69188391])

# Se crean los nodos y las aristas acorde al grafo
nodes = np.array([[i, j, k] for i, j, k in zip(x, y, z)])
edges = np.array([(nodes[u], nodes[v]) for u, v in G.edges()])

random_sizes = np.random.randint(50, 500, size=len(nodes))


# Se grafica
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111, projection="3d")

# Se grafican los nodos
ax.scatter(*nodes.T)  # Equivalente a ax.scatter(x, y, z)
# Se grafican las aristas
for edge in edges:
    ax.plot(*edge.T)

plt.show()

# %%
nodes
# Out:
# array([[-1.        , -0.13278077, -0.0675157 ],
#        [-0.74535599,  0.5418651 ,  0.11842486],
#        [-0.33333333,  0.81169596, -0.39102575],
#        [-0.33333333,  0.30381473, -0.89182412],
#        [ 0.33333333,  0.14755841, -0.91126968],
#        [ 0.74535599,  0.55886793, -0.42248934],
#        [ 0.33333333,  0.96932751, -0.10096091],
#        [ 0.33333333,  0.79691831,  0.58775964],
#        [-0.33333333,  0.53273201,  0.7233475 ],
#        [-0.33333333, -0.14755841,  0.91126968],
#        [-0.74535599, -0.55886793,  0.42248934],
#        [-0.33333333, -0.96932751,  0.10096091],
#        [ 0.33333333, -0.81169596,  0.39102575],
#        [ 0.33333333, -0.30381473,  0.89182412],
#        [ 0.74535599,  0.27990399,  0.69188391],
#        [ 1.        ,  0.13278077,  0.0675157 ],
#        [ 0.74535599, -0.5418651 , -0.11842486],
#        [ 0.33333333, -0.53273201, -0.7233475 ],
#        [-0.33333333, -0.79691831, -0.58775964],
#        [-0.74535599, -0.27990399, -0.69188391]])

# %%
df_nodes = pd.DataFrame(nodes)
df_nodes
# Out:
#            0         1         2
# 0  -1.000000 -0.132781 -0.067516
# 1  -0.745356  0.541865  0.118425
# 2  -0.333333  0.811696 -0.391026
# 3  -0.333333  0.303815 -0.891824
# 4   0.333333  0.147558 -0.911270
# 5   0.745356  0.558868 -0.422489
# 6   0.333333  0.969328 -0.100961
# 7   0.333333  0.796918  0.587760
# 8  -0.333333  0.532732  0.723348
# 9  -0.333333 -0.147558  0.911270
# 10 -0.745356 -0.558868  0.422489
# 11 -0.333333 -0.969328  0.100961
# 12  0.333333 -0.811696  0.391026
# 13  0.333333 -0.303815  0.891824
# 14  0.745356  0.279904  0.691884
# 15  1.000000  0.132781  0.067516
# 16  0.745356 -0.541865 -0.118425
# 17  0.333333 -0.532732 -0.723348
# 18 -0.333333 -0.796918 -0.587760
# 19 -0.745356 -0.279904 -0.691884

# %%
edges
# Out:
# array([[[-1.        , -0.13278077, -0.0675157 ],
#         [-0.74535599,  0.5418651 ,  0.11842486]],
#
#        [[-1.        , -0.13278077, -0.0675157 ],
#         [-0.74535599, -0.27990399, -0.69188391]],
#
#        [[-1.        , -0.13278077, -0.0675157 ],
#         [-0.74535599, -0.55886793,  0.42248934]],
#
#        [[-0.74535599,  0.5418651 ,  0.11842486],
#         [-0.33333333,  0.81169596, -0.39102575]],
#
#        [[-0.74535599,  0.5418651 ,  0.11842486],
#         [-0.33333333,  0.53273201,  0.7233475 ]],
#
#        [[-0.33333333,  0.81169596, -0.39102575],
#         [-0.33333333,  0.30381473, -0.89182412]],
#
#        [[-0.33333333,  0.81169596, -0.39102575],
#         [ 0.33333333,  0.96932751, -0.10096091]],
#
#        [[-0.33333333,  0.30381473, -0.89182412],
#         [ 0.33333333,  0.14755841, -0.91126968]],
#
#        [[-0.33333333,  0.30381473, -0.89182412],
#         [-0.74535599, -0.27990399, -0.69188391]],
#
#        [[ 0.33333333,  0.14755841, -0.91126968],
#         [ 0.74535599,  0.55886793, -0.42248934]],
#
#        [[ 0.33333333,  0.14755841, -0.91126968],
#         [ 0.33333333, -0.53273201, -0.7233475 ]],
#
#        [[ 0.74535599,  0.55886793, -0.42248934],
#         [ 0.33333333,  0.96932751, -0.10096091]],
#
#        [[ 0.74535599,  0.55886793, -0.42248934],
#         [ 1.        ,  0.13278077,  0.0675157 ]],
#
#        [[ 0.33333333,  0.96932751, -0.10096091],
#         [ 0.33333333,  0.79691831,  0.58775964]],
#
#        [[ 0.33333333,  0.79691831,  0.58775964],
#         [-0.33333333,  0.53273201,  0.7233475 ]],
#
#        [[ 0.33333333,  0.79691831,  0.58775964],
#         [ 0.74535599,  0.27990399,  0.69188391]],
#
#        [[-0.33333333,  0.53273201,  0.7233475 ],
#         [-0.33333333, -0.14755841,  0.91126968]],
#
#        [[-0.33333333, -0.14755841,  0.91126968],
#         [-0.74535599, -0.55886793,  0.42248934]],
#
#        [[-0.33333333, -0.14755841,  0.91126968],
#         [ 0.33333333, -0.30381473,  0.89182412]],
#
#        [[-0.74535599, -0.55886793,  0.42248934],
#         [-0.33333333, -0.96932751,  0.10096091]],
#
#        [[-0.33333333, -0.96932751,  0.10096091],
#         [ 0.33333333, -0.81169596,  0.39102575]],
#
#        [[-0.33333333, -0.96932751,  0.10096091],
#         [-0.33333333, -0.79691831, -0.58775964]],
#
#        [[ 0.33333333, -0.81169596,  0.39102575],
#         [ 0.33333333, -0.30381473,  0.89182412]],
#
#        [[ 0.33333333, -0.81169596,  0.39102575],
#         [ 0.74535599, -0.5418651 , -0.11842486]],
#
#        [[ 0.33333333, -0.30381473,  0.89182412],
#         [ 0.74535599,  0.27990399,  0.69188391]],
#
#        [[ 0.74535599,  0.27990399,  0.69188391],
#         [ 1.        ,  0.13278077,  0.0675157 ]],
#
#        [[ 1.        ,  0.13278077,  0.0675157 ],
#         [ 0.74535599, -0.5418651 , -0.11842486]],
#
#        [[ 0.74535599, -0.5418651 , -0.11842486],
#         [ 0.33333333, -0.53273201, -0.7233475 ]],
#
#        [[ 0.33333333, -0.53273201, -0.7233475 ],
#         [-0.33333333, -0.79691831, -0.58775964]],
#
#        [[-0.33333333, -0.79691831, -0.58775964],
#         [-0.74535599, -0.27990399, -0.69188391]]])

# %%
"""

¿Cuántos nodos tiene el grafo?, ¿con qué comando descubres el número de nodos?

20

"""

len(df_nodes)
# Out:
# 20

# %%
"""

¿Cuántas aristas tiene el grafo?, ¿con qué comando descubres el número de nodos?

30

"""

len(edges)
# Out:
# 30

# %%
"""

¿Qué hace el código G.degree()?

Dice el grado del nodo, es el número de conecciones de cada nodo 

"""

degrees = dict(G.degree())
degrees
# Out:
# {0: 3,
#  1: 3,
#  2: 3,
#  3: 3,
#  4: 3,
#  5: 3,
#  6: 3,
#  7: 3,
#  8: 3,
#  9: 3,
#  10: 3,
#  11: 3,
#  12: 3,
#  13: 3,
#  14: 3,
#  15: 3,
#  16: 3,
#  17: 3,
#  18: 3,
#  19: 3}

# %%
"""

¿Cuál es el número máximo de aristas en el grafo?

3, todos tienen 3

"""

degrees
# Out:
# {0: 3,
#  1: 3,
#  2: 3,
#  3: 3,
#  4: 3,
#  5: 3,
#  6: 3,
#  7: 3,
#  8: 3,
#  9: 3,
#  10: 3,
#  11: 3,
#  12: 3,
#  13: 3,
#  14: 3,
#  15: 3,
#  16: 3,
#  17: 3,
#  18: 3,
#  19: 3}

# %%
"""
¿Cuál es la diferencia entre animation2_1 y animation2_2?

La 2 tiene una animación y la 1 no. 
Aparte la 1 tiene "random_sizes = np.random.randint(50, 500, size=len(nodes))" que no hace nada en el codigo.

"""
# Out:
# '\n¿Cuál es la diferencia entre animation2_1 y animation2_2?\n\nLa 2 tiene una animación y la 1 no. \nAparte la 1 tiene "random_sizes = np.random.randint(50, 500, size=len(nodes))" que no hace nada en el codigo.\n\n'
