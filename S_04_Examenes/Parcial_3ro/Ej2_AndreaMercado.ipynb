# %%
# # Examen tercer parcial 
# Andrea Mercado Jiménez

# %%
import os
import sys
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Ejercicio 2: Analice el código en los archivos animation2_1 y animation2_2 y conteste lo siguiente:

# ¿Qué forma tiene el grafo?
# ¿Cuántos nodos tiene el grafo?, ¿con qué comando descubres el número de nodos?
# ¿Cuántas aristas tiene el grafo?, ¿con qué comando descubres el número de nodos?
# ¿Qué hace el código G.degree()?
# ¿Cuál es el número máximo de aristas en el grafo?
# ¿Cuál es la diferencia entre animation2_1 y animation2_2?

# %%
file_path_1 = r"C:\\Users\\andim\\OneDrive\\Escritorio\\Quinto Semestre\\Modelos Computacionales\\animation2_1.py"
file_path_2 = r"C:\\Users\\andim\\OneDrive\\Escritorio\\Quinto Semestre\\Modelos Computacionales\\animation2_2.py"

# %%
from animation2_1 import G as G1
from animation2_2 import G as G2

# %%
# Análisis de G1 (grafo de animation2_1)
print("Análisis del grafo G1 (animation2_1):")

# Pregunta 1: ¿Qué forma tiene el grafo?
print("¿Es dirigido?", G1.is_directed())

# Pregunta 2: ¿Cuántos nodos tiene el grafo?
num_nodos_G1 = G1.number_of_nodes()
print("\nNúmero de nodos en G1:", num_nodos_G1)

# Pregunta 3: ¿Cuántas aristas tiene el grafo?
num_aristas_G1 = G1.number_of_edges()
print("\nNúmero de aristas en G1:", num_aristas_G1)

# Pregunta 4: ¿Qué hace el código G.degree()?
print("\nGrado de todos los nodos en G1:")
print(dict(G1.degree()))

# Pregunta 5: ¿Cuál es el número máximo de aristas en el grafo?
if G1.is_directed():
    max_aristas_G1 = G1.number_of_nodes() * (G1.number_of_nodes() - 1)
else:
    max_aristas_G1 = (G1.number_of_nodes() * (G1.number_of_nodes() - 1)) // 2
print("\nNúmero máximo de aristas en G1:", max_aristas_G1)

# Análisis de G2 (grafo de animation2_2)
print("\nAnálisis del grafo G2 (animation2_2):")

# Pregunta 1: ¿Qué forma tiene el grafo?
print("¿Es dirigido?", G2.is_directed())

# Pregunta 2: ¿Cuántos nodos tiene el grafo?
num_nodos_G2 = G2.number_of_nodes()
print("\nNúmero de nodos en G2:", num_nodos_G2)

# Pregunta 3: ¿Cuántas aristas tiene el grafo?
num_aristas_G2 = G2.number_of_edges()
print("\nNúmero de aristas en G2:", num_aristas_G2)

# Pregunta 4: ¿Qué hace el código G.degree()?
print("\nGrado de todos los nodos en G2:")
print(dict(G2.degree()))

# Pregunta 5: ¿Cuál es el número máximo de aristas en el grafo?
if G2.is_directed():
    max_aristas_G2 = G2.number_of_nodes() * (G2.number_of_nodes() - 1)
else:
    max_aristas_G2 = (G2.number_of_nodes() * (G2.number_of_nodes() - 1)) // 2
print("\nNúmero máximo de aristas en G2:", max_aristas_G2)

# Pregunta 6: ¿Cuál es la diferencia entre animation2_1 y animation2_2?
print("\nComparación entre G1 y G2:")
print(f"¿Son los grafos G1 y G2 isomorfos? {nx.is_isomorphic(G1, G2)}")
print(f"¿Tienen el mismo número de nodos? {'Sí' if num_nodos_G1 == num_nodos_G2 else 'No'}")
print(f"¿Tienen el mismo número de aristas? {'Sí' if num_aristas_G1 == num_aristas_G2 else 'No'}")

# Visualización de los grafos
# Visualizar G1
plt.figure(figsize=(5, 5))
plt.title("Visualización de G1 (animation2_1)")
nx.draw(G1, with_labels=True, node_color="orchid", font_weight="bold", node_size=500)
plt.show()

# Visualizar G2
plt.figure(figsize=(5, 5))
plt.title("Visualización de G2 (animation2_2)")
nx.draw(G2, with_labels=True, node_color="lightgreen", font_weight="bold", node_size=500)
plt.show()
# Out:
# Análisis del grafo G1 (animation2_1):
# ¿Es dirigido? False
#
# Número de nodos en G1: 20
#
# Número de aristas en G1: 30
#
# Grado de todos los nodos en G1:
# {0: 3, 1: 3, 2: 3, 3: 3, 4: 3, 5: 3, 6: 3, 7: 3, 8: 3, 9: 3, 10: 3, 11: 3, 12: 3, 13: 3, 14: 3, 15: 3, 16: 3, 17: 3, 18: 3, 19: 3}
#
# Número máximo de aristas en G1: 190
#
# Análisis del grafo G2 (animation2_2):
# ¿Es dirigido? False
#
# Número de nodos en G2: 20
#
# Número de aristas en G2: 30
#
# Grado de todos los nodos en G2:
# {0: 3, 1: 3, 2: 3, 3: 3, 4: 3, 5: 3, 6: 3, 7: 3, 8: 3, 9: 3, 10: 3, 11: 3, 12: 3, 13: 3, 14: 3, 15: 3, 16: 3, 17: 3, 18: 3, 19: 3}
#
# Número máximo de aristas en G2: 190
#
# Comparación entre G1 y G2:
# ¿Son los grafos G1 y G2 isomorfos? True
# ¿Tienen el mismo número de nodos? Sí
# ¿Tienen el mismo número de aristas? Sí
