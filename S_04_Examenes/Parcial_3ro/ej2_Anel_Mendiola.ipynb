# %%
# Ejercicio 2: Analice el código en los archivos animation2_1 y animation2_2 y conteste lo siguiente:

# %%
import os
import sys
import networkx as nx
import matplotlib.pyplot as plt

# %%
file1 = r"C:\Users\ANEL\OneDrive\Escritorio\database\animation2_1"
file2 = r"C:\Users\ANEL\OneDrive\Escritorio\database\animation2_2"

# %%
from animation2_1 import G as G1
from animation2_2 import G as G2

# %%
# análisis del grafo animation2_1

plt.figure(figsize=(5, 5))
plt.title("Visualización de G1 (animation2_1)")
nx.draw(G1, with_labels=True, node_color="darkgreen", font_weight="bold", node_size=500)
plt.show()

# %%
# 1. ¿Qué forma tiene el grafo?
print("¿Es dirigido?", G1.is_directed())
# Out:
# ¿Es dirigido? False

# %%
# 2. ¿Cuántos nodos tiene el grafo?
numG1 = G1.number_of_nodes()
print("\nNúmero de nodos en G1 =", numG1)
# Out:
# Número de nodos en G1 = 20

# %%
# 3. ¿Cuántas aristas tiene el grafo?
aristasG1 = G1.number_of_edges()
print("\nNúmero de aristas en G1 =", aristasG1)
# Out:
# Número de aristas en G1 = 30

# %%
# 4. ¿Qué hace el código G.degree()?
print("\nGrado de todos los nodos en G1 = ")
print(dict(G1.degree()))  # Muestra el grado de todos los nodos en un arreglo de diccionario
# Out:
# Grado de todos los nodos en G1 =
# {0: 3, 1: 3, 2: 3, 3: 3, 4: 3, 5: 3, 6: 3, 7: 3, 8: 3, 9: 3, 10: 3, 11: 3, 12: 3, 13: 3, 14: 3, 15: 3, 16: 3, 17: 3, 18: 3, 19: 3}

# %%
# 5. ¿Cuál es el número máximo de aristas en el grafo?
if G1.is_directed():
    aristasG1 = G1.number_of_nodes() * (G1.number_of_nodes() - 1)
else:
    aristasG1 = (G1.number_of_nodes() * (G1.number_of_nodes() - 1)) // 2
print("\nNúmero máximo de aristas en G1 = ", aristasG1)
# Out:
# Número máximo de aristas en G1 =  190

# %%
# análisis del grafo animation2_2
plt.figure(figsize=(5, 5))
plt.title("Visualización de G2 (animation2_2)")
nx.draw(G2, with_labels=True, node_color="olive", font_weight="bold", node_size=500)
plt.show()

# %%
# Pregunta 1: ¿Qué forma tiene el grafo?
print("¿Es dirigido?", G2.is_directed())
# Out:
# ¿Es dirigido? False

# %%
# 2. ¿Cuántos nodos tiene el grafo?
numG2 = G2.number_of_nodes()
print("\nNúmero de nodos en G2= ", numG2)
# Out:
# Número de nodos en G2=  20

# %%
# 3. ¿Cuántas aristas tiene el grafo?
aristasG2 = G2.number_of_edges()
print("\nNúmero de aristas en G2 =", aristasG2)
# Out:
# Número de aristas en G2 = 30

# %%
# 4. ¿Qué hace el código G.degree()?
print("\nGrado de todos los nodos en G1 = ")
print(dict(G1.degree())) # muestra el diciconario
# Out:
# Grado de todos los nodos en G1 =
# {0: 3, 1: 3, 2: 3, 3: 3, 4: 3, 5: 3, 6: 3, 7: 3, 8: 3, 9: 3, 10: 3, 11: 3, 12: 3, 13: 3, 14: 3, 15: 3, 16: 3, 17: 3, 18: 3, 19: 3}

# %%
# 5. ¿Cuál es el número máximo de aristas en el grafo?
if G2.is_directed():
    aristasG2 = G2.number_of_nodes() * (G2.number_of_nodes() - 1)
else:
    aristasG2 = (G2.number_of_nodes() * (G2.number_of_nodes() - 1)) // 2
print("\nNúmero máximo de aristas en G2 = ", aristasG2)
# Out:
# Número máximo de aristas en G2 =  190

# %%
# 6. ¿Cuál es la diferencia entre animation2_1 y animation2_2?
print("\nComparación entre G1 y G2:")
print(f"¿Son los grafos G1 y G2 isomorfos? {nx.is_isomorphic(G1, G2)}")
print(f"¿Tienen el mismo número de nodos? {'Sí' if numG1 == numG2 else 'No'}")
print(f"¿Tienen el mismo número de aristas? {'Sí' if aristasG1 == aristasG2 else 'No'}")

# en animation2_1 se muestra el grafo en un espacio 3D y también se muestra un histograma
# en animation2_2 sí se ve cómo gira el grafo, puedes verlo desde diferentes ángulos
# Out:
# Comparación entre G1 y G2:
# ¿Son los grafos G1 y G2 isomorfos? True
# ¿Tienen el mismo número de nodos? Sí
# ¿Tienen el mismo número de aristas? Sí
