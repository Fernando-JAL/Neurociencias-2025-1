# %%
# Examen Segundo Parcial 
# Andrea Mercado Jiménez

# %%
import pandas as pd

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=12, micro=2, releaselevel='final', serial=0)

# %%
import pandas as pd 
pd.__version__
# Out:
# '2.2.2'

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\andim\miniconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andim\miniconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\andim\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import sys 
print(sys.executable)
# Out:
# C:\Users\andim\miniconda3\python.exe

# %%
import pandas as pd
import numpy as np
import pandas as pd

# %%
# Cargar base de datos 
import pandas as pd 
ruta_archivo = r"C:\\Users\\andim\\OneDrive\\Escritorio\\Quinto Semestre\\Modelos Computacionales\\1- mental-illnesses-prevalence.csv"
df = pd.read_csv(ruta_archivo)

df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.713314
# 1                                           4.702100
# 2                                           4.683743
# 3                                           4.673549
# 4                                           4.670810
#
#    Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.703023
# 1                                           0.702069
# 2                                           0.700792
# 3                                           0.700087
# 4                                           0.699898
#
#    Eating disorders (share of population) - Sex: Both - Age: Age-standardized
# 0                                           0.127700
# 1                                           0.123256
# 2                                           0.118844
# 3                                           0.115089
# 4                                           0.111815

# %%
# Crear un diccionario con los nombres antiguos como claves y los nuevos nombres como valores
nuevos_nombres = {
    "Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized": "Schizophrenia disorders",
    "Depressive disorders (share of population) - Sex: Both - Age: Age-standardized": "Depressive disorders",
    "Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized": "Anxiety disorders",
    "Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized": "Bipolar disorders",
    "Eating disorders (share of population) - Sex: Both - Age: Age-standardized": "Eating disorders"
}

# Renombrar las columnas usando el método .rename()
df = df.rename(columns=nuevos_nombres)

# Verificar los cambios mostrando los nombres de las columnas
print(df.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'Schizophrenia disorders',
#        'Depressive disorders', 'Anxiety disorders', 'Bipolar disorders',
#        'Eating disorders'],
#       dtype='object')

# %%
# Crear una función llamada "df_ordered" que reciba un dataframe y un str y retorne un dataframe ordenado de mayor a menor considerando la característica str
def df_ordered(dataframe, nombre_columna):
    if nombre_columna in dataframe.columns:
        return dataframe.sort_values(by=nombre_columna, ascending=False)
    else:
        return f"La columna '{nombre_columna}' no existe en el dataframe."

# %%
df_ordered_result = df_ordered(df, 'Eating disorders')
df_ordered_result.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders  Depressive disorders  \
# 389  Australia  AUS  2019                 0.388646              4.382458
# 388  Australia  AUS  2018                 0.388518              4.360289
# 387  Australia  AUS  2017                 0.388469              4.360807
# 386  Australia  AUS  2016                 0.388526              4.440195
# 385  Australia  AUS  2015                 0.388578              4.534077
#
#      Anxiety disorders  Bipolar disorders  Eating disorders
# 389           5.815165           1.125061          1.031688
# 388           5.820752           1.125041          1.028413
# 387           5.812073           1.125032          1.025406
# 386           5.677490           1.125020          1.020526
# 385           5.544162           1.125010          1.015827

# %%
import matplotlib.pyplot as plt

# Crear una función llamada "plot_bar" que reciba un dataframe y un str y haga el plot de barras de ese dataframe considerando esa caracterísitca descrita por el string
import matplotlib.pyplot as plt

# Crear una función llamada "plot_bar" que reciba un dataframe y un str y haga el plot de barras de ese dataframe
def plot_bar(dataframe, nombre_columna):
    if nombre_columna in dataframe.columns:
        # Ordenar el DataFrame de mayor a menor por la columna dada
        df_sorted = dataframe.sort_values(by=nombre_columna, ascending=False)

        # Crear la figura
        plt.figure(figsize=(10, 6))
        plt.bar(df_sorted['Entity'], df_sorted[nombre_columna], color='pink')
        
        # Etiquetas y títulos
        plt.xlabel('Entity')
        plt.ylabel(nombre_columna)
        plt.title(f'Gráfico de barras de: {nombre_columna}')
        
        # Rotación de las etiquetas del eje X para mejor legibilidad
        plt.xticks(rotation=90)
        
        # Ajustar diseño
        plt.tight_layout()
        
        # Mostrar el gráfico
        plt.show()
    else: 
        print(f"La columna '{nombre_columna}' no existe en el dataframe.")

# %%
plot_bar(df, 'Bipolar disorders')

# %%
# Países con mayor depresión
import pandas as pd
import matplotlib.pyplot as plt

# Reemplazar "<0.1" por 0.1 y convertir a numérico
df['Depressive disorders'] = df['Depressive disorders'].replace("<0.1", 0.1).apply(pd.to_numeric, errors='coerce')

depresion_paises = df.groupby('Entity')['Depressive disorders'].sum()

print(depresion_paises)

# Agrupar por 'Entity' y sumar los valores de 'Eating disorders'
TCA_paises = df.groupby('Entity', as_index=False)['Depressive disorders'].sum()

# Crear función para graficar ordenadamente
def plot_bar(dataframe, nombre_columna):
    if nombre_columna in dataframe.columns:
        # Ordenar el DataFrame de mayor a menor
        df_sorted = dataframe.sort_values(by=nombre_columna, ascending=False)

        # Crear la figura
        plt.figure(figsize=(10, 6))
        plt.bar(df_sorted['Entity'], df_sorted[nombre_columna], color='pink')
        
        # Etiquetas y títulos
        plt.xlabel('Entity')
        plt.ylabel(nombre_columna)
        plt.title(f'Gráfico de barras de: {nombre_columna}')
        
        # Rotación de las etiquetas del eje X para mejor legibilidad
        plt.xticks(rotation=90)
        
        # Ajustar diseño
        plt.tight_layout()
        
        # Mostrar el gráfico
        plt.show()
    else: 
        print(f"La columna '{nombre_columna}' no existe en el dataframe.")
# Out:
# Entity
# Afghanistan           149.042151
# Africa (IHME GBD)     136.739586
# Albania                73.038789
# Algeria               123.967471
# America (IHME GBD)    110.756721
#                          ...
# Vietnam                76.130376
# World                 105.355325
# Yemen                 146.912638
# Zambia                125.735835
# Zimbabwe              100.373028
# Name: Depressive disorders, Length: 214, dtype: float64

# %%
# Gráfica de barras mostrando el valor de depresión y la entidad (país)
plot_bar(df, 'Depressive disorders')

# %%
# Países con mayor desorden alimenticio
import pandas as pd
import matplotlib.pyplot as plt

# Reemplazar "<0.1" por 0.1 y convertir a numérico
df['Eating disorders'] = df['Eating disorders'].replace("<0.1", 0.1).apply(pd.to_numeric, errors='coerce')

TCA_paises = df.groupby('Entity')['Eating disorders'].sum()

print(TCA_paises)

# Agrupar por 'Entity' y sumar los valores de 'Eating disorders'
TCA_paises = df.groupby('Entity', as_index=False)['Eating disorders'].sum()

# Crear la función para graficar ordenadamente
def plot_bar(dataframe, nombre_columna):
    if nombre_columna in dataframe.columns:
        # Ordenar el DataFrame de mayor a menor
        df_sorted = dataframe.sort_values(by=nombre_columna, ascending=False)

        # Crear la figura
        plt.figure(figsize=(10, 6))
        plt.bar(df_sorted['Entity'], df_sorted[nombre_columna], color='pink')

        # Etiquetas y títulos
        plt.xlabel('Entity')
        plt.ylabel(nombre_columna)
        plt.title(f'Gráfico de barras de: {nombre_columna}')

        # Rotación de etiquetas en el eje X para mejor legibilidad
        plt.xticks(rotation=90)

        # Ajustar diseño
        plt.tight_layout()

        # Mostrar el gráfico
        plt.show()
    else:
        print(f"La columna '{nombre_columna}' no existe en el dataframe.")
# Out:
# Entity
# Afghanistan           3.206056
# Africa (IHME GBD)     3.383387
# Albania               3.418702
# Algeria               5.851010
# America (IHME GBD)    8.984045
#                         ...
# Vietnam               2.263044
# World                 4.745392
# Yemen                 4.034012
# Zambia                3.011127
# Zimbabwe              3.074208
# Name: Eating disorders, Length: 214, dtype: float64

# %%
# Gráfica de barras mostrando el valor de desorden alimenticio y la entidad (país)
plot_bar(df, 'Eating disorders')

# %%
# Países con mayor esquizofrenia
df['Schizophrenia disorders'] = df['Schizophrenia disorders'].replace("<0.1", 0.1).apply(pd.to_numeric, errors='coerce')
esquizofrenia_paises = df.groupby('Entity')['Schizophrenia disorders'].sum()
print(esquizofrenia_paises)

# Agrupar por 'Entity' y sumar los valores de 'Schizophrenia disorders'
esquizofrenia_paises = df.groupby('Entity', as_index=False)['Schizophrenia disorders'].sum()

# Crear la función para graficar ordenadamente
def plot_bar(dataframe, nombre_columna):
    if nombre_columna in dataframe.columns:
        # Ordenar el DataFrame de mayor a menor
        df_sorted = dataframe.sort_values(by=nombre_columna, ascending=False)

        # Crear la figura
        plt.figure(figsize=(10, 6))
        plt.bar(df_sorted['Entity'], df_sorted[nombre_columna], color='pink')

        # Etiquetas y títulos
        plt.xlabel('Entity')
        plt.ylabel(nombre_columna)
        plt.title(f'Gráfico de barras de: {nombre_columna}')

        # Rotación de etiquetas en el eje X para mejor legibilidad
        plt.xticks(rotation=90)

        # Ajustar diseño
        plt.tight_layout()

        # Mostrar el gráfico
        plt.show()
    else:
        print(f"La columna '{nombre_columna}' no existe en el dataframe.")
# Out:
# Entity
# Afghanistan            6.514178
# Africa (IHME GBD)      6.595280
# Albania                8.500528
# Algeria                7.471716
# America (IHME GBD)    10.259163
#                         ...
# Vietnam                9.437347
# World                  8.666304
# Yemen                  6.929568
# Zambia                 6.272372
# Zimbabwe               6.134306
# Name: Schizophrenia disorders, Length: 214, dtype: float64

# %%
# Gráfica de barras mostrando el valor de esquizofrenia y la entidad (país)
plot_bar(df, 'Schizophrenia disorders')

# %%
# Crear un data frame con los valores por país de ["Entity Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
columnas = ["Entity", "Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
df_selected = df[columnas]
df_selected.head()
# Out:
#         Entity Code  Year  Schizophrenia disorders  Depressive disorders  \
# 0  Afghanistan  AFG  1990                 0.223206              4.996118
# 1  Afghanistan  AFG  1991                 0.222454              4.989290
# 2  Afghanistan  AFG  1992                 0.221751              4.981346
# 3  Afghanistan  AFG  1993                 0.220987              4.976958
# 4  Afghanistan  AFG  1994                 0.220183              4.977782
#
#    Anxiety disorders  Bipolar disorders  Eating disorders
# 0           4.713314           0.703023          0.127700
# 1           4.702100           0.702069          0.123256
# 2           4.683743           0.700792          0.118844
# 3           4.673549           0.700087          0.115089
# 4           4.670810           0.699898          0.111815

# %%
# Mostrar los estadísticos del dataframe anterior
df_selected.describe(include='all')
# Out:
#              Entity  Code         Year  Schizophrenia disorders  \
# count          6420  6150  6420.000000              6420.000000
# unique          214   205          NaN                      NaN
# top     Afghanistan   AFG          NaN                      NaN
# freq             30    30          NaN                      NaN
# mean            NaN   NaN  2004.500000                 0.266604
# std             NaN   NaN     8.656116                 0.039383
# min             NaN   NaN  1990.000000                 0.188416
# 25%             NaN   NaN  1997.000000                 0.242267
# 50%             NaN   NaN  2004.500000                 0.273477
# 75%             NaN   NaN  2012.000000                 0.286575
# max             NaN   NaN  2019.000000                 0.462045
#
#         Depressive disorders  Anxiety disorders  Bipolar disorders  \
# count            6420.000000        6420.000000        6420.000000
# unique                   NaN                NaN                NaN
# top                      NaN                NaN                NaN
# freq                     NaN                NaN                NaN
# mean                3.767036           4.101840           0.636968
# std                 0.925286           1.050543           0.233391
# min                 1.522333           1.879996           0.181667
# 25%                 3.080036           3.425846           0.520872
# 50%                 3.636772           3.939547           0.579331
# 75%                 4.366252           4.564164           0.844406
# max                 7.645899           8.624634           1.506730
#
#         Eating disorders
# count        6420.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            0.195664
# std             0.138380
# min             0.044780
# 25%             0.096416
# 50%             0.144150
# 75%             0.251167
# max             1.031688

# %%
# Mostrar la distribución de cada feature del dataframe anterior
import seaborn as sns

# Definir las columnas a graficar
columns_to_plot = ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]

# Crear la figura
plt.figure(figsize=(12, 10))

# Graficar cada columna en un subplot
for m, col in enumerate(columns_to_plot, 1):
    plt.subplot(2, 3, m)  # Crear una cuadrícula de 2x3

    # Ordenar los valores de la columna de mayor a menor (aunque es un histograma)
    sorted_data = df[col].dropna().sort_values(ascending=False)

    # Crear el histograma con KDE
    sns.histplot(sorted_data, kde=True, color='purple')

    # Configurar los títulos y etiquetas
    plt.title(f'Distribución de: {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')

# Ajustar el diseño para evitar superposiciones
plt.tight_layout()

# Mostrar la figura
plt.show()

# %%
# Mostrar en un mapa de color la correlación entre las features ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
col_data = ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]

df_nueva = df[col_data].dropna()

corr_mat = df_nueva.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_mat, annot=True, cmap='plasma', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Mental Health Disorders')
plt.show()

# %%
# Del dataset cancer_reg visto en clase, determinar:

archivo_cancer = r"C:\\Users\\andim\\OneDrive\\Escritorio\\Quinto Semestre\\Modelos Computacionales\\cancer_reg.csv"
df = pd.read_csv(archivo_cancer)
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
#    ...  pctprivatecoveragealone  pctempprivcoverage pctpubliccoverage  \
# 0  ...                      NaN                41.6              32.9
# 1  ...                     53.8                43.6              31.1
# 2  ...                     43.5                34.9              42.1
# 3  ...                     40.3                35.0              45.3
# 4  ...                     43.9                35.1              44.0
#
#    pctpubliccoveragealone   pctwhite  pctblack  pctasian  pctotherrace  \
# 0                    14.0  81.780529  2.594728  4.821857      1.843479
# 1                    15.3  89.228509  0.969102  2.246233      3.741352
# 2                    21.1  90.922190  0.739673  0.465898      2.747358
# 3                    25.0  91.744686  0.782626  1.161359      1.362643
# 4                    22.7  94.104024  0.270192  0.665830      0.492135
#
#    pctmarriedhouseholds  birthrate
# 0             52.856076   6.118831
# 1             45.372500   4.333096
# 2             54.444868   3.729488
# 3             51.021514   4.603841
# 4             54.027460   6.796657
#
# [5 rows x 33 columns]

# %%
# La correlación entre las features [ 'target_deathrate', 'avganncount', 'avgdeathsperyear', 'incidencerate', 'medincome', 'povertypercent', 'pctprivatecoverage', 'pctpubliccoverage' ]

columnas = ['target_deathrate', 'avganncount', 'avgdeathsperyear','incidencerate', 'medincome', 'povertypercent','pctprivatecoverage', 'pctpubliccoverage']
matrix = df[columnas].corr()
matrix
# Out:
#                     target_deathrate  avganncount  avgdeathsperyear  \
# target_deathrate            1.000000    -0.143532         -0.090715
# avganncount                -0.143532     1.000000          0.939408
# avgdeathsperyear           -0.090715     0.939408          1.000000
# incidencerate               0.449432     0.073553          0.062690
# medincome                  -0.428615     0.269145          0.223207
# povertypercent              0.429389    -0.135694         -0.066918
# pctprivatecoverage         -0.386066     0.132244          0.056183
# pctpubliccoverage           0.404572    -0.173548         -0.131687
#
#                     incidencerate  medincome  povertypercent  \
# target_deathrate         0.449432  -0.428615        0.429389
# avganncount              0.073553   0.269145       -0.135694
# avgdeathsperyear         0.062690   0.223207       -0.066918
# incidencerate            1.000000  -0.001036        0.009046
# medincome               -0.001036   1.000000       -0.788965
# povertypercent           0.009046  -0.788965        1.000000
# pctprivatecoverage       0.105174   0.724175       -0.822534
# pctpubliccoverage        0.046109  -0.754822        0.651162
#
#                     pctprivatecoverage  pctpubliccoverage
# target_deathrate             -0.386066           0.404572
# avganncount                   0.132244          -0.173548
# avgdeathsperyear              0.056183          -0.131687
# incidencerate                 0.105174           0.046109
# medincome                     0.724175          -0.754822
# povertypercent               -0.822534           0.651162
# pctprivatecoverage            1.000000          -0.720012
# pctpubliccoverage            -0.720012           1.000000

# %%
# Mostrar la distribución de cada feature del dataframe anterior
plt.figure(figsize=(12, 10))
for i, column in enumerate(columnas, 1):
    plt.subplot(4, 2, i)
    sns.histplot(df[column], kde=True, bins=30, color= 'orange')
    plt.title(f'Distribución de: {column}')
    plt.tight_layout()

plt.show()

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\andim\miniconda3\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\andim\miniconda3\lib\site-packages (from scipy) (1.26.4)

# %%
from scipy.stats import linregress

# Filtrar solo las columnas numéricas
df_numeric = df.select_dtypes(include='number')

# Verifica si hay datos faltantes
print("Datos faltantes:\n", df_numeric.isnull().sum())

# Opcional: Elimina filas con valores faltantes (si aplica)
df_numeric = df_numeric.dropna()

# Generar la matriz de correlación solo con datos numéricos
matrix = df_numeric.corr()

# Definir un umbral para relaciones lineales fuertes
threshold = 0.7 

# Encontrar pares de columnas con correlación fuerte
columnas_sel = df_numeric.columns  # Seleccionar columnas numéricas
corr_alta = [
    (col1, col2) for col1 in columnas_sel for col2 in columnas_sel
    if col1 != col2 and abs(matrix.loc[col1, col2]) > threshold
]

# Calcular la regresión lineal para cada par altamente correlacionado
for col1, col2 in corr_alta:
    slope, intercept, r_value, p_value, std_err = linregress(df_numeric[col1], df_numeric[col2])
    print(f"Linear regression between {col1} and {col2}:")
    print(f"Slope: {slope}, Intercept: {intercept}, R-squared: {r_value**2}\n")
# Out:
# Datos faltantes:
#  avganncount                   0
# avgdeathsperyear              0
# target_deathrate              0
# incidencerate                 0
# medincome                     0
# popest2015                    0
# povertypercent                0
# studypercap                   0
# medianage                     0
# medianagemale                 0
# medianagefemale               0
# percentmarried                0
# pctnohs18_24                  0
# pcths18_24                    0
# pctsomecol18_24            2285
# pctbachdeg18_24               0
# pcths25_over                  0
# pctbachdeg25_over             0
# pctemployed16_over          152
# pctunemployed16_over          0
# pctprivatecoverage            0
# pctprivatecoveragealone     609
# pctempprivcoverage            0
# pctpubliccoverage             0
# pctpubliccoveragealone        0
# pctwhite                      0
# pctblack                      0
# pctasian                      0
# pctotherrace                  0
# pctmarriedhouseholds          0
# birthrate                     0
# dtype: int64
# Linear regression between avganncount and avgdeathsperyear:
# Slope: 0.3452945006304496, Intercept: -36.18896606793436, R-squared: 0.9290689936283905
#
# Linear regression between avganncount and popest2015:
# Slope: 244.23737992536834, Intercept: -52094.62291730048, R-squared: 0.9168452252354662
#
# Linear regression between avgdeathsperyear and avganncount:
# Slope: 2.6906567927727405, Intercept: 145.76948306285442, R-squared: 0.9290689936283905
#
# Linear regression between avgdeathsperyear and popest2015:
# Slope: 703.5021460244338, Intercept: -25733.614066449358, R-squared: 0.9761891420321203
#
# Linear regression between medincome and povertypercent:
# Slope: -0.00043411922529067794, Intercept: 37.141045931739725, R-squared: 0.6337611528348565
#
# Linear regression between medincome and pctbachdeg25_over:
# Slope: 0.0003247882247457299, Intercept: -2.121570697369844, R-squared: 0.5015906726922855
#
# Linear regression between medincome and pctprivatecoverage:
# Slope: 0.0006691290445918935, Intercept: 33.1297993028261, R-squared: 0.5328112099266415
#
# Linear regression between medincome and pctprivatecoveragealone:
# Slope: 0.0006843254887507335, Intercept: 16.563290557710282, R-squared: 0.6189439600020968
#
# Linear regression between medincome and pctempprivcoverage:
# Slope: 0.0006342702519152603, Intercept: 11.70314865585259, R-squared: 0.5744856762918936
#
# Linear regression between medincome and pctpubliccoverage:
# Slope: -0.0005074174186596416, Intercept: 60.058350503032386, R-squared: 0.5841479431641944
#
# Linear regression between medincome and pctpubliccoveragealone:
# Slope: -0.00038339969459880765, Intercept: 37.23559563780324, R-squared: 0.5381901033484247
#
# Linear regression between popest2015 and avganncount:
# Slope: 0.0037539103372122096, Intercept: 252.29641798265908, R-squared: 0.9168452252354662
#
# Linear regression between popest2015 and avgdeathsperyear:
# Slope: 0.0013876135951377973, Intercept: 40.456463717488134, R-squared: 0.9761891420321203
#
# Linear regression between povertypercent and medincome:
# Slope: -1459.878107011967, Intercept: 71446.65699296459, R-squared: 0.6337611528348565
#
# Linear regression between povertypercent and pctemployed16_over:
# Slope: -0.9243683062744146, Intercept: 69.92690646063038, R-squared: 0.5552175925484932
#
# Linear regression between povertypercent and pctprivatecoverage:
# Slope: -1.3688808404356112, Intercept: 87.49288815289565, R-squared: 0.6630973676408357
#
# Linear regression between povertypercent and pctprivatecoveragealone:
# Slope: -1.185811291457245, Intercept: 68.57960629101275, R-squared: 0.5526491204110242
#
# Linear regression between povertypercent and pctpubliccoveragealone:
# Slope: 0.7576183491942612, Intercept: 6.533426070344227, R-squared: 0.6249216558443954
#
# Linear regression between medianagemale and medianagefemale:
# Slope: 0.9182480484875243, Intercept: 5.721316906232623, R-squared: 0.8626942743862764
#
# Linear regression between medianagefemale and medianagemale:
# Slope: 0.9395002535613856, Intercept: 0.05845727106477483, R-squared: 0.8626942743862764
#
# Linear regression between percentmarried and pctmarriedhouseholds:
# Slope: 0.8169001848693546, Intercept: 8.929120048482261, R-squared: 0.7165629800925729
#
# Linear regression between pcths18_24 and pctsomecol18_24:
# Slope: -0.9086424637023243, Intercept: 72.743601812517, R-squared: 0.5920271361587477
#
# Linear regression between pctsomecol18_24 and pcths18_24:
# Slope: -0.65155125344516, Intercept: 61.746268014234616, R-squared: 0.5920271361587477
#
# Linear regression between pcths25_over and pctbachdeg25_over:
# Slope: -0.5698441614472894, Intercept: 33.25392790106632, R-squared: 0.5586308236413704
#
# Linear regression between pctbachdeg25_over and medincome:
# Slope: 1544.3622473843402, Intercept: 26718.08536820542, R-squared: 0.5015906726922855
#
# Linear regression between pctbachdeg25_over and pcths25_over:
# Slope: -0.9803220975758715, Intercept: 48.167719151885926, R-squared: 0.5586308236413704
#
# Linear regression between pctemployed16_over and povertypercent:
# Slope: -0.6006454232363818, Intercept: 49.43945305390871, R-squared: 0.5552175925484932
#
# Linear regression between pctemployed16_over and pctprivatecoverage:
# Slope: 0.9764382177272818, Intercept: 11.415693700444749, R-squared: 0.5192331680255036
#
# Linear regression between pctemployed16_over and pctprivatecoveragealone:
# Slope: 0.9928749108154482, Intercept: -5.3313654256666965, R-squared: 0.5962580666898907
#
# Linear regression between pctemployed16_over and pctempprivcoverage:
# Slope: 0.867733595017954, Intercept: -5.729484575065072, R-squared: 0.492065187238172
#
# Linear regression between pctemployed16_over and pctpubliccoverage:
# Slope: -0.7202400288525171, Intercept: 75.42347672553045, R-squared: 0.538599462244757
#
# Linear regression between pctemployed16_over and pctpubliccoveragealone:
# Slope: -0.5517761665588566, Intercept: 49.25765042314636, R-squared: 0.5101258779316353
#
# Linear regression between pctprivatecoverage and medincome:
# Slope: 796.2757172670736, Intercept: -4407.233903741682, R-squared: 0.5328112099266415
#
# Linear regression between pctprivatecoverage and povertypercent:
# Slope: -0.48440839264710733, Intercept: 48.01637303504768, R-squared: 0.6630973676408357
#
# Linear regression between pctprivatecoverage and pctemployed16_over:
# Slope: 0.5317624388300264, Intercept: 20.116224486742027, R-squared: 0.5192331680255036
#
# Linear regression between pctprivatecoverage and pctprivatecoveragealone:
# Slope: 0.8895535717275808, Intercept: -8.716843943053277, R-squared: 0.8788535712617351
#
# Linear regression between pctprivatecoverage and pctempprivcoverage:
# Slope: 0.753322193352598, Intercept: -7.130564047763414, R-squared: 0.680986422481144
#
# Linear regression between pctprivatecoverage and pctpubliccoverage:
# Slope: -0.5351334814426754, Intercept: 70.76313824255169, R-squared: 0.5459624404456614
#
# Linear regression between pctprivatecoverage and pctpubliccoveragealone:
# Slope: -0.5101981701115041, Intercept: 52.162448318957914, R-squared: 0.8008595983333683
#
# Linear regression between pctprivatecoveragealone and medincome:
# Slope: 904.4584341466025, Intercept: 2941.3441477706947, R-squared: 0.6189439600020968
#
# Linear regression between pctprivatecoveragealone and povertypercent:
# Slope: -0.46605149098544424, Intercept: 39.44275751494812, R-squared: 0.5526491204110242
#
# Linear regression between pctprivatecoveragealone and pctemployed16_over:
# Slope: 0.6005369459886782, Intercept: 25.192910677164114, R-squared: 0.5962580666898907
#
# Linear regression between pctprivatecoveragealone and pctprivatecoverage:
# Slope: 0.9879714940101184, Intercept: 16.438155122711827, R-squared: 0.8788535712617351
#
# Linear regression between pctprivatecoveragealone and pctempprivcoverage:
# Slope: 0.8882610646360167, Intercept: -1.7672132908779759, R-squared: 0.8524832888751142
#
# Linear regression between pctprivatecoveragealone and pctpubliccoverage:
# Slope: -0.6665024434624187, Intercept: 68.68443646000458, R-squared: 0.7625524201031944
#
# Linear regression between pctprivatecoveragealone and pctpubliccoveragealone:
# Slope: -0.5205460579863139, Intercept: 44.57935078312401, R-squared: 0.7506277389497787
#
# Linear regression between pctempprivcoverage and medincome:
# Slope: 905.74274066482, Intercept: 9413.109889848842, R-squared: 0.5744856762918936
#
# Linear regression between pctempprivcoverage and pctemployed16_over:
# Slope: 0.5670694209182839, Intercept: 30.915477029981197, R-squared: 0.492065187238172
#
# Linear regression between pctempprivcoverage and pctprivatecoverage:
# Slope: 0.9039776452761472, Intercept: 27.05441749814961, R-squared: 0.680986422481144
#
# Linear regression between pctempprivcoverage and pctprivatecoveragealone:
# Slope: 0.9597215535102135, Intercept: 8.887335069348204, R-squared: 0.8524832888751142
#
# Linear regression between pctempprivcoverage and pctpubliccoverage:
# Slope: -0.6294568508402485, Intercept: 62.337355867302165, R-squared: 0.6294967885537407
#
# Linear regression between pctempprivcoverage and pctpubliccoveragealone:
# Slope: -0.46264271515355593, Intercept: 38.41893524344219, R-squared: 0.5487734847880789
#
# Linear regression between pctpubliccoverage and medincome:
# Slope: -1151.2177581669127, Intercept: 88698.94749402044, R-squared: 0.5841479431641944
#
# Linear regression between pctpubliccoverage and pctemployed16_over:
# Slope: -0.7478055102031069, Intercept: 81.53389956648981, R-squared: 0.538599462244757
#
# Linear regression between pctpubliccoverage and pctprivatecoverage:
# Slope: -1.020235996024379, Intercept: 101.52631130044175, R-squared: 0.5459624404456614
#
# Linear regression between pctpubliccoverage and pctprivatecoveragealone:
# Slope: -1.1441104643845037, Intercept: 90.1579310393079, R-squared: 0.7625524201031944
#
# Linear regression between pctpubliccoverage and pctempprivcoverage:
# Slope: -1.0000634478970862, Intercept: 77.7300459506996, R-squared: 0.6294967885537407
#
# Linear regression between pctpubliccoverage and pctpubliccoveragealone:
# Slope: 0.6878968654908063, Intercept: -5.693879428993053, R-squared: 0.7636365987715269
#
# Linear regression between pctpubliccoveragealone and medincome:
# Slope: -1403.7311738382857, Intercept: 73989.0024788631, R-squared: 0.5381901033484247
#
# Linear regression between pctpubliccoveragealone and povertypercent:
# Slope: 0.8248502118632809, Intercept: 0.8834051785828088, R-squared: 0.6249216558443954
#
# Linear regression between pctpubliccoveragealone and pctemployed16_over:
# Slope: -0.9245159701496845, Intercept: 72.22220676281859, R-squared: 0.5101258779316353
#
# Linear regression between pctpubliccoveragealone and pctprivatecoverage:
# Slope: -1.5697030002250691, Intercept: 94.74419005051496, R-squared: 0.8008595983333683
#
# Linear regression between pctpubliccoveragealone and pctprivatecoveragealone:
# Slope: -1.4420006211429501, Intercept: 76.44011717328841, R-squared: 0.7506277389497787
#
# Linear regression between pctpubliccoveragealone and pctempprivcoverage:
# Slope: -1.1861712436257321, Intercept: 64.31298825893874, R-squared: 0.5487734847880789
#
# Linear regression between pctpubliccoveragealone and pctpubliccoverage:
# Slope: 1.1101033266472016, Intercept: 14.8755098740241, R-squared: 0.7636365987715269
#
# Linear regression between pctwhite and pctblack:
# Slope: -0.7241891306863796, Intercept: 69.72209726471493, R-squared: 0.6786912336113223
#
# Linear regression between pctblack and pctwhite:
# Slope: -0.9371740127721403, Intercept: 92.40381818179672, R-squared: 0.6786912336113223
#
# Linear regression between pctmarriedhouseholds and percentmarried:
# Slope: 0.8771732377648702, Intercept: 6.875214574453281, R-squared: 0.7165629800925729
