# %% [markdown]
# Examen 2
#
# Alisson García Mejía

# %%
import pandas as pd 
#Cargamos archivos 
csv_path= r"C:\Users\aliss\Downloads\1- mental-illnesses-prevalence.csv"
df_mental = pd.read_csv(csv_path)
df_mental
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %%
csv_path = r"C:\Users\aliss\Downloads\2- burden-disease-from-each-mental-illness(1).csv"

df_burden = pd.read_csv(csv_path)

df_burden
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Depressive disorders  \
# 0                                             895.22565
# 1                                             893.88434
# 2                                             892.34973
# 3                                             891.51587
# 4                                             891.39160
# ...                                                 ...
# 6835                                          546.46204
# 6836                                          547.27765
# 6837                                          547.62270
# ...

# %%
csv_path = r"C:\Users\aliss\Downloads\3- adult-population-covered-in-primary-data-on-the-prevalence-of-major-depression.csv"

df_prevalencia_depresion = pd.read_csv(csv_path)

df_prevalencia_depresion
# Out:
#                          Entity      Code  Year  Major depression
# 0          Andean Latin America       NaN  2008               0.0
# 1                  Asia Pacific       NaN  2008              80.8
# 2                   Australasia       NaN  2008             100.0
# 3                     Caribbean       NaN  2008               9.1
# 4                  Central Asia       NaN  2008               0.0
# 5                Central Europe       NaN  2008              16.0
# 6         Central Latin America       NaN  2008              49.8
# 7    Central Sub-Saharan Africa       NaN  2008               0.0
# 8                     East Asia       NaN  2008              12.2
# 9       East Sub-Saharan Africa       NaN  2008               1.3
# 10               Eastern Europe       NaN  2008              23.6
# 11     North Africa/Middle East       NaN  2008              47.0
# 12                North America       NaN  2008             100.0
# ...

# %%
import pandas as pd 
csv_path = r"C:\Users\aliss\Downloads\4- adult-population-covered-in-primary-data-on-the-prevalence-of-mental-illnesses.csv"

df_desordenes = pd.read_csv(csv_path)

df_desordenes
# Out:
#                          Entity      Code  Year  Major depression  \
# 0          Andean Latin America       NaN  2008               0.0
# 1                  Asia Pacific       NaN  2008              80.8
# 2                   Australasia       NaN  2008             100.0
# 3                     Caribbean       NaN  2008               9.1
# 4                  Central Asia       NaN  2008               0.0
# 5                Central Europe       NaN  2008              16.0
# 6         Central Latin America       NaN  2008              49.8
# 7    Central Sub-Saharan Africa       NaN  2008               0.0
# 8                     East Asia       NaN  2008              12.2
# 9       East Sub-Saharan Africa       NaN  2008               1.3
# 10               Eastern Europe       NaN  2008              23.6
# 11     North Africa/Middle East       NaN  2008              47.0
# 12                North America       NaN  2008             100.0
# ...

# %%
csv_path = r"C:\Users\aliss\Downloads\5- anxiety-disorders-treatment-gap.csv"
df_ansiedad = pd.read_csv(csv_path)
df_ansiedad
# Out:
#                            Entity Code  Year  \
# 0                       Argentina  ARG  2015
# 1         Beijing/Shanghai, China  NaN  2005
# 2                         Belgium  BEL  2002
# 3                        Bulgaria  BGR  2006
# 4                        Colombia  COL  2012
# 5                          France  FRA  2002
# 6                         Germany  DEU  2003
# 7           High-income countries  NaN  2017
# 8                            Iraq  IRQ  2007
# 9                          Israel  ISR  2004
# 10                          Italy  ITA  2002
# 11                          Japan  JPN  2006
# 12                        Lebanon  LBN  2003
# 13  Lower-middle-income countries  NaN  2017
# 14             Medellin, Colombia  NaN  2012
# 15                         Mexico  MEX  2002
# 16                  Murcia, Spain  NaN  2012
# 17                    Netherlands  NLD  2003
# 18                        Nigeria  NGA  2004
# 19                           Peru  PER  2005
# ...

# %%
csv_path = r"C:\Users\aliss\Downloads\6- depressive-symptoms-across-us-population.csv"

df_sintomas_depresivos = pd.read_csv(csv_path)

df_sintomas_depresivos
# Out:
#                      Entity  Code  Year  Nearly every day  \
# 0           Appetite change   NaN  2014               4.6
# 1   Average across symptoms   NaN  2014               4.4
# 2            Depressed mood   NaN  2014               3.6
# 3  Difficulty concentrating   NaN  2014               3.5
# 4          Loss of interest   NaN  2014               4.4
# 5                Low energy   NaN  2014               9.0
# 6           Low self-esteem   NaN  2014               3.0
# 7     Psychomotor agitation   NaN  2014               1.9
# 8            Sleep problems   NaN  2014               9.2
# 9         Suicidal ideation   NaN  2014               0.6
#
#    More than half the days  Several days  Not at all
# 0                      5.1          15.5        74.8
# 1                      4.3          15.0        76.3
# 2                      3.9          16.8        75.7
# 3                      3.6          10.9        82.1
# 4                      5.4          16.3        73.8
# ...

# %%
csv_path = r"C:\Users\aliss\Downloads\7- number-of-countries-with-primary-data-on-prevalence-of-mental-illnesses-in-the-global-burden-of-disease-study.csv"

df_prevalencia_global = pd.read_csv(csv_path)
df_prevalencia_global
# Out:
#                                       Entity  Code  Year  \
# 0                      Alcohol use disorders   NaN  2019
# 1                  Amphetamine use disorders   NaN  2019
# 2                           Anorexia nervosa   NaN  2019
# 3                          Anxiety disorders   NaN  2019
# 4   Attention-deficit hyperactivity disorder   NaN  2019
# 5                  Autism spectrum disorders   NaN  2019
# 6                           Bipolar disorder   NaN  2019
# 7                            Bulimia nervosa   NaN  2019
# 8                     Cannabis use disorders   NaN  2019
# 9                      Cocaine use disorders   NaN  2019
# 10                                 Dysthymia   NaN  2019
# 11                 Major depressive disorder   NaN  2019
# 12                      Opioid use disorders   NaN  2019
# 13                  Other drug use disorders   NaN  2019
# 14                     Personality disorders   NaN  2019
#
# ...

# %% [markdown]
# Examen
#
# 1. Crear una función llamada "df_ordered" que reciba un dataframe y un str y retorne un dataframe ordenado de mayor a menor considerando la característica str

# %%
data = df_prevalencia_global
def df_ordered(df, column):
    return df.sort_values(by=column, ascending=False)

df = pd.DataFrame(data)

df_ordered(df, 'Number of countries with primary data on prevalence of mental disorders')
# Out:
#                                       Entity  Code  Year  \
# 4   Attention-deficit hyperactivity disorder   NaN  2019
# 8                     Cannabis use disorders   NaN  2019
# 11                 Major depressive disorder   NaN  2019
# 9                      Cocaine use disorders   NaN  2019
# 3                          Anxiety disorders   NaN  2019
# 1                  Amphetamine use disorders   NaN  2019
# 0                      Alcohol use disorders   NaN  2019
# 6                           Bipolar disorder   NaN  2019
# 10                                 Dysthymia   NaN  2019
# 5                  Autism spectrum disorders   NaN  2019
# 7                            Bulimia nervosa   NaN  2019
# 12                      Opioid use disorders   NaN  2019
# 2                           Anorexia nervosa   NaN  2019
# 13                  Other drug use disorders   NaN  2019
# 14                     Personality disorders   NaN  2019
#
# ...

# %% [markdown]
# 2. Crear una función llamada "plot_bar" que reciba un dataframe y un str y haga el plot de barras de ese dataframe considerando esa característica descrita por el string

# %%
data = df_sintomas_depresivos
def plot_bar(df, column):
    df = pd.DataFrame(data)  
    (plt.bar(df.index, df[column], color='blue'))
    plt.ylabel('Índice')
    plt.xlabel(column)
    plt.title(column, fontsize=16)
    
    #Para ponerle su valor encima de cada barra :0
    for i, value in enumerate(df[column]):
        plt.text(i, value, str(round(value, 2)), ha='center')
        
    plt.show()
    
    
plot_bar(df_sintomas_depresivos,'Not at all')

# %% [markdown]
# 3. Ordenar países con mayor depresión

# %%
data = df_prevalencia_depresion
def df_ordered(df, column):
    return df.sort_values(by=column, ascending=False)

df = pd.DataFrame(data)

df_ordered(df, 'Major depression')
# Out:
#                          Entity      Code  Year  Major depression
# 2                   Australasia       NaN  2008             100.0
# 12                North America       NaN  2008             100.0
# 1                  Asia Pacific       NaN  2008              80.8
# 20               Western Europe       NaN  2008              73.6
# 6         Central Latin America       NaN  2008              49.8
# 11     North Africa/Middle East       NaN  2008              47.0
# 19      West Sub-Saharan Africa       NaN  2008              46.6
# 21                        World  OWID_WRL  2008              35.4
# 10               Eastern Europe       NaN  2008              23.6
# 16       Southern Latin America       NaN  2008              16.5
# 5                Central Europe       NaN  2008              16.0
# 15               Southeast Asia       NaN  2008              14.5
# 8                     East Asia       NaN  2008              12.2
# ...

# %% [markdown]
# 4. Realiza una gráfica de barras mostrando el valor de depresión y la entidad (país)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
data4 = df_prevalencia_depresion

def plot_multiple_bar(df,category_column, value_columns):
    index = np.arange(len(df[category_column]))
    
    
    for i, col in enumerate(value_columns):
        plt.barh(index + i, df[col], label=col, color='#20B2AA')
        
    plt.yticks(index, df[category_column])
    plt.xlabel("Valor de depresión")
    plt.title("Valor de depresión en cada entidad")

plot_multiple_bar(data4, 'Entity', ['Major depression'])

# %% [markdown]
# 5. Ordena países con mayor desorden alimenticio

# %%
data = df_desordenes
df = pd.DataFrame(data)

desorden_alimenticio = df.sort_values(by='Eating disorders', ascending=False)

desorden_alimenticio[['Entity', 'Eating disorders']]
# Out:
#                          Entity  Eating disorders
# 12                North America              89.8
# 6         Central Latin America              71.0
# 20               Western Europe              57.3
# 1                  Asia Pacific              23.1
# 18       Tropical Latin America              21.1
# 5                Central Europe              18.8
# 2                   Australasia              16.4
# 21                        World              15.2
# 8                     East Asia               7.9
# 9       East Sub-Saharan Africa               0.1
# 4                  Central Asia               0.0
# 3                     Caribbean               0.0
# 0          Andean Latin America               0.0
# 7    Central Sub-Saharan Africa               0.0
# 13                      Oceania               0.0
# 11     North Africa/Middle East               0.0
# 10               Eastern Europe               0.0
# 14                   South Asia               0.0
# ...

# %% [markdown]
# 6. Gráfica de barras mostrando el valor de desorden alimenticio y la entidad (país)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

def plot_multiple_bar(df, category_column, value_columns):
    index = np.arange(len(df[category_column]))
    
    for i, col in enumerate(value_columns):
        plt.barh(index + i, df[col], label=col, color='pink')
    
    plt.yticks(index, df[category_column])
    plt.xlabel("Valor de desordenes alimenticios")
    plt.title("Desordenes alimenticios por entidad")
    
plot_multiple_bar(df_desordenes, "Entity",["Eating disorders"])

# %% [markdown]
# 7. Países con mayor esquizofrenia

# %%
data = df_desordenes
df = pd.DataFrame(data)

desorden_alimenticio = df.sort_values(by='Schizophrenia', ascending=False)

desorden_alimenticio[['Entity', 'Schizophrenia']]
# Out:
#                          Entity Schizophrenia
# 17  Southern Sub-Saharan Africa          <0.1
# 12                North America          89.8
# 2                   Australasia          85.1
# 1                  Asia Pacific          71.6
# 9       East Sub-Saharan Africa           6.4
# 14                   South Asia           6.3
# 3                     Caribbean          28.3
# 8                     East Asia          15.6
# 21                        World          14.2
# 20               Western Europe          12.6
# 10               Eastern Europe           1.3
# 6         Central Latin America           0.7
# 13                      Oceania           0.4
# 15               Southeast Asia           0.4
# 19      West Sub-Saharan Africa             0
# 18       Tropical Latin America             0
# 0          Andean Latin America             0
# 16       Southern Latin America             0
# 7    Central Sub-Saharan Africa             0
# ...

# %% [markdown]
# 8. Gráfica de barras mostrando el valor de esquizofrenia y la entidad (país)

# %%
data = df_desordenes
df = pd.DataFrame(data)

def plot_multiple_bar(df, category_column, value_columns):
    index = np.arange(len(df[category_column]))
    
    for i, col in enumerate(value_columns):
        plt.barh(index + i, df[col], label=col, color='orange')
    
    plt.yticks(index, df[category_column])
    plt.xlabel("Valor de esquizofrenia")
    plt.title("Esquizofrenia por entidad")
    
plot_multiple_bar(df_desordenes, "Entity",["Schizophrenia"])

# %% [markdown]
# 9. Crear un dataframe con los valores por país de  ["Entity Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]

# %%
columnas = ['Entity', 'Code', "Year",'DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Schizophrenia', 'DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Depressive disorders', 'DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Anxiety disorders','DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Bipolar disorder', 'DALYs (rate) - Sex: Both - Age: Age-standardized - Cause: Eating disorders']

df_filtered = df_burden[columnas]

df_filtered.columns = ["Entity", "Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders",  "Eating disorders"]

df_filtered
# Out:
#            Entity Code  Year  Schizophrenia disorders  Depressive disorders  \
# 0     Afghanistan  AFG  1990               138.248250             895.22565
# 1     Afghanistan  AFG  1991               137.761220             893.88434
# 2     Afghanistan  AFG  1992               137.080300             892.34973
# 3     Afghanistan  AFG  1993               136.486020             891.51587
# 4     Afghanistan  AFG  1994               136.183230             891.39160
# ...           ...  ...   ...                      ...                   ...
# 6835     Zimbabwe  ZWE  2015               127.108720             546.46204
# 6836     Zimbabwe  ZWE  2016               127.142105             547.27765
# 6837     Zimbabwe  ZWE  2017               127.465050             547.62270
# 6838     Zimbabwe  ZWE  2018               127.681210             546.57184
# 6839     Zimbabwe  ZWE  2019               128.216030             544.53160
#
# ...

# %% [markdown]
# 10. Mostrar los estadísticos del dataframe anterior

# %%
df_filtered.describe()
# Out:
#               Year  Schizophrenia disorders  Depressive disorders  \
# count  6840.000000              6840.000000           6840.000000
# mean   2004.500000               171.090876            652.215475
# std       8.656074                26.234514            183.643326
# min    1990.000000               119.913380            243.097840
# 25%    1997.000000               155.950035            506.857413
# 50%    2004.500000               175.115100            640.099150
# 75%    2012.000000               183.999005            765.842910
# max    2019.000000               291.100100           1427.423600
#
#        Anxiety disorders  Bipolar disorders  Eating disorders
# count        6840.000000        6840.000000       6840.000000
# mean          392.942475         137.930619         42.392972
# std           100.820728          51.197175         29.394380
# min           180.049640          39.438133          9.671199
# ...

# %% [markdown]
# 11. Mostrar la distribución de cada feature del dataframe anterior

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 

data=df_mental 
df = pd.DataFrame(data)
plt.figure(figsize=(15,10))

indice = ["Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized","Depressive disorders (share of population) - Sex: Both - Age: Age-standardized","Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized", "Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized", "Eating disorders (share of population) - Sex: Both - Age: Age-standardized"]

df_filtered = df_mental[indice]

for m, col in enumerate(indice, 1):
    plt.subplot(2, 3, m)
    sns.histplot(df_filtered[col], kde=True, color='green')
    plt.title(f'Distribución de: {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 12. Mostrar en un mapa de color la correlación entre las features ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data=df_mental 
df = pd.DataFrame(data)

features =[ 'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized',
       'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized',
       'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized',
       'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized',
       'Eating disorders (share of population) - Sex: Both - Age: Age-standardized']


df_filter = df_mental[features]
corr = df_filter.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='viridis', vmin=-1, vmax=1)
plt.title('Correlación de desordenes mentales')
plt.show()

# %% [markdown]
# En base al dataset cancer_reg visto en clase, determinar:
#
# 13. La correlación entre las features [ 'target_deathrate', 'avganncount', 'avgdeathsperyear', 'incidencerate', 'medincome', 'povertypercent', 'pctprivatecoverage', 'pctpubliccoverage' ]

# %%
csv_path = r"C:\Users\aliss\Downloads\cancer_reg.csv"

df_cancer = pd.read_csv(csv_path)

import pandas as pd 

features2 = [ 'target_deathrate', 'avganncount', 'avgdeathsperyear', 'incidencerate', 'medincome', 'povertypercent', 'pctprivatecoverage', 'pctpubliccoverage' ]

df_filter = df_cancer[features2]
corr = df_filter.corr()
corr
# Out:
#                     target_deathrate  avganncount  avgdeathsperyear  \
# target_deathrate            1.000000    -0.143532         -0.090715
# avganncount                -0.143532     1.000000          0.939408
# avgdeathsperyear           -0.090715     0.939408          1.000000
# incidencerate               0.449432     0.073553          0.062690
# medincome                  -0.428615     0.269145          0.223207
# povertypercent              0.429389    -0.135694         -0.066918
# pctprivatecoverage         -0.386066     0.132244          0.056183
# pctpubliccoverage           0.404572    -0.173548         -0.131687
#
#                     incidencerate  medincome  povertypercent  \
# target_deathrate         0.449432  -0.428615        0.429389
# avganncount              0.073553   0.269145       -0.135694
# avgdeathsperyear         0.062690   0.223207       -0.066918
# incidencerate            1.000000  -0.001036        0.009046
# ...

# %% [markdown]
# 14. Mostrar la distribución de cada feature del dataframe anterior

# %%
import seaborn as sns

sns.pairplot(df_filter, markers="o")

# %% [markdown]
# 15. Aquellos que dependencia lineal encontrar los valores de la recta. hint:scipy

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

df_cancer = pd.read_csv(csv_path)

pd.read_csv(csv_path)

features_dependencia_lineal = ['avganncount', 'avgdeathsperyear']

ft_dependientes_lineales = df_cancer[features_dependencia_lineal]
corr = ft_dependientes_lineales.corr()
corr

df= pd.DataFrame(ft_dependientes_lineales)
df.to_csv("dependientes_lineales")

# Cargar los datos desde un archivo CSV
df = pd.read_csv('dependientes_lineales')

# Asignar las columnas correspondientes
x = df['avganncount']
y = df['avgdeathsperyear']

# Calcular la recta de mejor ajuste (regresión lineal)
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Mostrar los resultados de la regresión
print(f"Pendiente (slope): {slope}")
print(f"Intersección (intercept): {intercept}")
print(f"Coeficiente de correlación (r_value): {r_value}")
print(f"Error estándar (std_err): {std_err}")

# Generar los valores de y de acuerdo con la recta de regresión
y_pred = slope * x + intercept

# Graficar los datos y la recta de mejor ajuste
plt.scatter(x, y, label='Datos')
plt.plot(x, y_pred, color='red', label=f'Recta de mejor ajuste: y = {slope:.2f}x + {intercept:.2f}')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')
plt.title('Recta de regresión lineal')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Pendiente (slope): 0.33437045310825686
# Intersección (intercept): -16.775825554463864
# Coeficiente de correlación (r_value): 0.9394077833002423
# Error estándar (std_err): 0.0022111748125440873
