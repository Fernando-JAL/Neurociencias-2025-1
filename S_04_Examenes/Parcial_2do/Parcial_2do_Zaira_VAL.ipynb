# %% [markdown]
# # Examen 2: Zaira Valentina Ávila Lazcano
# ## Parte 1: Mental health
#
# [dataset](https://www.kaggle.com/datasets/imtkaggleteam/mental-health)

# %% [markdown]
# - Crear una función llamada "df_ordered" que reciba un dataframe y un str y retorne un dataframe ordenado de mayor a menor considerando la característica str
# - Crear una función llamada "plot_bar" que reciba un dataframe y un str y haga el plot de barras de ese dataframe considerando esa caracterísitca descrita por el string
# - países con mayor depresión
# - gráfica de barras mostrando el valor de depresión y la entidad (país)
# - países con mayor desorden alimenticio
# - gráfica de barras mostrando el valor de desorden alimenticio y la entidad (país)
# - países con mayor esquizofrenia
# - gráfica de barras mostrando el valor de esquizofrenia y la entidad (país)
# - crear un data frame con los valores por país de ["Entity	Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
# - mostrar los estadísticos del dataframe anterior
# - mostrar la distribución de cada feature del dataframe anterior
# - mostrar en un mapa de color la correlación entre las features ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]

# %%
#from cgitb import strong
#from lib2to3.pytree import convert

#import pandas as pd
import sys
sys.version_info
#import matplotlib.pyplot as plt
import pandas as pd
pd. __version__

import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3.12

# %%
#import pandas as pd
#import numpy as np
#import pandas as pd

# %%
import pandas as pd
#import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos desde el archivo CSV
df = pd.read_csv('4- adult-population.csv')

df.head()
# Out:
#                  Entity Code  Year  Major depression  Bipolar disorder  \
# 0  Andean Latin America  NaN  2008               0.0               0.0
# 1          Asia Pacific  NaN  2008              80.8               3.8
# 2           Australasia  NaN  2008             100.0             100.0
# 3             Caribbean  NaN  2008               9.1               0.0
# 4          Central Asia  NaN  2008               0.0               0.0
#
#    Eating disorders  Dysthymia Schizophrenia  Anxiety disorders
# 0               0.0        0.0             0                0.0
# 1              23.1        1.0          71.6               93.1
# 2              16.4      100.0          85.1              100.0
# 3               0.0        0.0          28.3                0.0
# 4               0.0        0.0             0                0.0

# %%
#Crear una función llamada "df_ordered" que reciba un dataframe y un str y retorne un dataframe ordenado de mayor a menor considerando la característica str
def df_ordered(df, column):
    return df.sort_values(by=column, ascending=False)

# %%
df_ordered_result = df_ordered(df, 'Major depression')
df_ordered_result.head()
# Out:
#                    Entity Code  Year  Major depression  Bipolar disorder  \
# 2             Australasia  NaN  2008             100.0             100.0
# 12          North America  NaN  2008             100.0              89.8
# 1            Asia Pacific  NaN  2008              80.8               3.8
# 20         Western Europe  NaN  2008              73.6              19.0
# 6   Central Latin America  NaN  2008              49.8              34.5
#
#     Eating disorders  Dysthymia Schizophrenia  Anxiety disorders
# 2               16.4      100.0          85.1              100.0
# 12              89.8       90.2          89.8               93.4
# 1               23.1        1.0          71.6               93.1
# 20              57.3        7.5          12.6               81.8
# 6               71.0       46.0           0.7               69.7

# %%
# Crear una función llamada "plot_bar" que reciba un dataframe y un str y haga el plot de barras de ese dataframe considerando esa caracterísitca descrita por el string 

import matplotlib.pyplot as plt


def plot_bar(df, column):
    df_sorted = df_ordered(df, column)
    plt.figure(figsize=(10, 8))
    plt.bar(df_sorted['Entity'], df_sorted[column], color='pink')
    plt.xlabel('País')
    plt.ylabel(column)
    plt.title(f'{column} por País')
    plt.xticks(rotation=90)
    plt.show()

# %%
df_filtered = df[['Entity', 'Schizophrenia', 'Major depression', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders']]

# %%
# Países con mayor depresión
df_depression = df_ordered(df, 'Major depression')
print(df_depression[['Entity', 'Major depression']].head(10))
# Out:
#                       Entity  Major depression
# 2                Australasia             100.0
# 12             North America             100.0
# 1               Asia Pacific              80.8
# 20            Western Europe              73.6
# 6      Central Latin America              49.8
# 11  North Africa/Middle East              47.0
# 19   West Sub-Saharan Africa              46.6
# 21                     World              35.4
# 10            Eastern Europe              23.6
# 16    Southern Latin America              16.5

# %%
# Gráfica de barras mostrando el valor de depresión y la entidad (país)

plot_bar(df, 'Major depression')

# %%
# Países con mayor desorden alimenticio
df_eating = df_ordered(df, 'Eating disorders')
print(df_eating[['Entity', 'Eating disorders']].head(10))
# Out:
#                      Entity  Eating disorders
# 12            North America              89.8
# 6     Central Latin America              71.0
# 20           Western Europe              57.3
# 1              Asia Pacific              23.1
# 18   Tropical Latin America              21.1
# 5            Central Europe              18.8
# 2               Australasia              16.4
# 21                    World              15.2
# 8                 East Asia               7.9
# 9   East Sub-Saharan Africa               0.1

# %%
# Gráfica de barras mostrando el valor de desorden alimenticio y la entidad (país)
plot_bar(df, 'Major depression')
#plot_bar(df, 'Major depression', color)

# %%
#df_filtered

# %%
#df_filtered.dtypes

# %%
#convertir de los strings a flotantes, elegir mi class str y cambiar el valor de <0.1 a 0 y despues pasar toda eaa fila a flotante
#def convert_str_to_float(df, column):
    
    #for i, val in df[column].items():
        # Reemplazar el valor '<0.1' con 0
       # if isinstance(val, str) and val == '<0.1':
            #df.loc[i, column] = 0.0  # Usar .loc para asignar de forma segura
        # Convertir strings numéricos a float
       # elif isinstance(val, str):
           # try:
               # df.loc[i, column] = float(val)
           # except ValueError:
               # print(f"Error al convertir el valor: {val}")
    
    # Convertir toda la columna a tipo float usando .loc
    #df.loc[:, column] = df[column].astype(float)

    #return df

# Aplicar la función a la columna 'Schizophrenia disorders'
#df_filtered = convert_str_to_float(df_filtered, "Schizophrenia disorders")

# Mostrar los tipos de los valores en la columna después de la conversión
#for val in df_filtered["Schizophrenia disorders"]:
    #print(type(val), val)

# %%
#df_filtered

# %%
#for val in df_filtered.loc[:, "Schizophrenia disorders"]:
    #print(type(val), val)

# %%
# Países con mayor esquizofrenia
#df_schizo = df_ordered(df, 'Schizophrenia disorders')
#print(df_schizo[['Entity', 'Schizophrenia disorders']].head(10))
df.loc[17, 'Schizophrenia']=0.0
df['Schizophrenia'] = pd.to_numeric(df['Schizophrenia'])
p_esquizofrenia = df_ordered(df, 'Schizophrenia')
p_esquizofrenia
# Out:
#                          Entity      Code  Year  Major depression  \
# 12                North America       NaN  2008             100.0
# 2                   Australasia       NaN  2008             100.0
# 1                  Asia Pacific       NaN  2008              80.8
# 3                     Caribbean       NaN  2008               9.1
# 8                     East Asia       NaN  2008              12.2
# 21                        World  OWID_WRL  2008              35.4
# 20               Western Europe       NaN  2008              73.6
# 9       East Sub-Saharan Africa       NaN  2008               1.3
# 14                   South Asia       NaN  2008               1.7
# 10               Eastern Europe       NaN  2008              23.6
# 6         Central Latin America       NaN  2008              49.8
# 13                      Oceania       NaN  2008               0.0
# 15               Southeast Asia       NaN  2008              14.5
# ...

# %%
# Gráfica de barras mostrando el valor de esquizofrenia y la entidad (país)
plot_bar(df, 'Schizophrenia')

# %%
# Mostrar los estadísticos del dataframe anterior
statistics = df_filtered.describe()
print(statistics)
# Out:
#        Major depression  Anxiety disorders  Bipolar disorder  Eating disorders
# count         22.000000          22.000000         22.000000         22.000000
# mean          28.995455          34.181818         15.931818         14.577273
# std           33.230042          35.825870         28.352431         25.455918
# min            0.000000           0.000000          0.000000          0.000000
# 25%            1.400000           0.925000          0.000000          0.000000
# 50%           15.250000          23.900000          2.750000          0.000000
# 75%           46.900000          63.925000         14.100000         18.200000
# max          100.000000         100.000000        100.000000         89.800000

# %%
# Crear un data frame con los valores por país de ["Entity	Code", "Year", "Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
#["Major depression", "Bipolar disorder","Eating disorders", "Dysthymia", "Schizophrenia", "Anxiety disorders"]

df_filtered = df[["Entity", "Code","Major depression", "Bipolar disorder","Eating disorders", "Dysthymia", "Schizophrenia", "Anxiety disorders"]]

df_filtered.columns = ['Entity', 'Code', 'Major depression', 'Bipolar disorder', 'Eating disorders', 'Dysthymia', 'Schizophrenia', 'Anxiety disorders']

# %%
# Mostrar la distribución de cada feature del dataframe anterior
df_filtered.hist(bins=20, figsize=(14, 10), color='pink')
plt.show()

# %%
#Mostrar en un mapa de color la correlación entre las features ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
# Selecting relevant columns for correlation analysis
#col_data = ["Major depression", "Bipolar disorder", "Eating disorders", "Schizophrenia", "Anxiety disorders"]

# Cleaning the data by dropping rows with missing values
#df_nueva = df[col_data].dropna()

# Calculating the correlation matrix
#corr_mat = df_nueva.corr()

# Plotting the heatmap
#plt.figure(figsize=(8, 6))
#sns.heatmap(corr_mat, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
#plt.title('Correlation Matrix of Mental Health Disorders')
#plt.show()

# %%
#Mostrar en un mapa de color la correlación entre las features ["Schizophrenia disorders", "Depressive disorders", "Anxiety disorders", "Bipolar disorders", "Eating disorders"]
# Mostrar un mapa de calor de la correlación entre las características especificadas
#plt.figure(figsize=(10, 8))
#sns.heatmap(df_filtered[columns_to_convert].corr(), annot=True, cmap='magma')
#plt.title('Correlación entre Trastornos Mentales')
#plt.show()

# Convertir las columnas especificadas
col_convert = ['Major depression', 'Bipolar disorder', 'Eating disorders', 'Dysthymia', 'Schizophrenia', 'Anxiety disorders']
df[col_convert] = df[col_convert].apply(pd.to_numeric, errors='coerce')

#for column in columns_to_convert:
    #df_filtered = convert_str_to_float(df_filtered, column)

# Mostrar un mapa de calor de la correlación entre las características especificadas
plt.figure(figsize=(10, 8))
sns.heatmap(df[col_convert].corr(), annot=True, cmap='coolwarm')
plt.title('Correlación entre Trastornos Mentales')
plt.show()

# %% [markdown]
# ## Parte 2: Cancer
#
# Del dataset cancer_reg visto en clase, determinar:
# - La correlación entre las features [
#     'target_deathrate', 'avganncount', 'avgdeathsperyear',
#     'incidencerate', 'medincome', 'povertypercent',
#     'pctprivatecoverage', 'pctpubliccoverage'
# ]
# - Mostrar la distribución de cada feature del dataframe anterior
# - Aquellos con dependencia lineal, encontrar los valores de la recta.
# hint: scipy

# %%
#import pandas as pd
#csv_cr = "cancer_reg.csv"

#df_cr = pd.read_csv(csv_cr)
#df.head()
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Cargar el dataset
df = pd.read_csv('cancer_reg.csv')
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
#La correlación entre las features [    'target_deathrate', 'avganncount', 'avgdeathsperyear',  'incidencerate', 'medincome', 'povertypercent',  'pctprivatecoverage', 'pctpubliccoverage']

#correlacion = ['target_deathrate', 'avganncount', 'avgdeathsperyear',  'incidencerate', 'medincome', 'povertypercent',  'pctprivatecoverage', 'pctpubliccoverage']
#df_filtered = df_cr[correlacion]
#corr = df_filtered.corr()
#corr.style.background_gradient(cmap='coolwarm')
features = ['target_deathrate', 'avganncount', 'avgdeathsperyear', 'incidencerate', 'medincome', 'povertypercent', 'pctprivatecoverage', 'pctpubliccoverage']
df_selec = df[features]

# %%
matriz_corre = df_selec.corr()
print("Matriz de Correlación:")
print(matriz_corre)
# Out:
# Matriz de Correlación:
#                     target_deathrate  avganncount  avgdeathsperyear  \
# target_deathrate            1.000000    -0.143532         -0.090715
# avganncount                -0.143532     1.000000          0.939408
# avgdeathsperyear           -0.090715     0.939408          1.000000
# incidencerate               0.449432     0.073553          0.062690
# medincome                  -0.428615     0.269145          0.223207
# povertypercent              0.429389    -0.135694         -0.066918
# pctprivatecoverage         -0.386066     0.132244          0.056183
# pctpubliccoverage           0.404572    -0.173548         -0.131687
#
#                     incidencerate  medincome  povertypercent  \
# target_deathrate         0.449432  -0.428615        0.429389
# avganncount              0.073553   0.269145       -0.135694
# avgdeathsperyear         0.062690   0.223207       -0.066918
# incidencerate            1.000000  -0.001036        0.009046
# ...

# %%
#Mostrar la distribución de cada feature del dataframe anterior

fig, axes = plt.subplots(2, 4, figsize=(20, 10))
for i, feature in enumerate(features):
    row = i // 4
    col = i % 4
    sns.histplot(df_selec[feature], kde=True, ax=axes[row, col], color='yellow')
    axes[row, col].set_title(f'Distribución de {feature}')
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
#Aquellos con dependencia lineal encontrar los valores de la recta.(hint: scipy)

#sns.pairplot(df_filtered, markers='p')
sns.pairplot(df_selec, markers='p')
plt.show()

#correlaciones fuertes
threshold = 0.8
strong_corr = matriz_corre[(matriz_corre > threshold) | (matriz_corre < -threshold)]
print("Correlaciones Fuertes (|r| > 0.8):")
print(strong_corr)
# Out:
# Correlaciones Fuertes (|r| > 0.8):
#                     target_deathrate  avganncount  avgdeathsperyear  \
# target_deathrate                 1.0          NaN               NaN
# avganncount                      NaN     1.000000          0.939408
# avgdeathsperyear                 NaN     0.939408          1.000000
# incidencerate                    NaN          NaN               NaN
# medincome                        NaN          NaN               NaN
# povertypercent                   NaN          NaN               NaN
# pctprivatecoverage               NaN          NaN               NaN
# pctpubliccoverage                NaN          NaN               NaN
#
#                     incidencerate  medincome  povertypercent  \
# target_deathrate              NaN        NaN             NaN
# avganncount                   NaN        NaN             NaN
# avgdeathsperyear              NaN        NaN             NaN
# incidencerate                 1.0        NaN             NaN
# ...

# %%
# Seleccionar las características de dependencia lineal
features_depend_lineal = ['avganncount', 'avgdeathsperyear']

# %%
# Filtrar las características dependientes lineales
ft_depend_lineales = df_selec[features_depend_lineal]
corr = ft_depend_lineales.corr()
print(corr)
# Out:
#                   avganncount  avgdeathsperyear
# avganncount          1.000000          0.939408
# avgdeathsperyear     0.939408          1.000000

# %%
# Guardar las características dependientes lineales en un nuevo archivo CSV
df = pd.DataFrame(ft_depend_lineales)
df.to_csv("depend_lineales.csv", index=False)

# %%
# Cargar los datos desde el archivo CSV
df = pd.read_csv('depend_lineales.csv')

# %%
# Asignar las columnas correspondientes
x = df['avganncount']
y = df['avgdeathsperyear']

# %%
# Calcular la recta de mejor ajuste (regresión lineal)
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# %%
# Mostrar los resultados de la regresión
print(f"Pendiente (slope): {slope}")
print(f"Intersección (intercept): {intercept}")
print(f"Coeficiente de correlación (r_value): {r_value}")
print(f"Error estándar (std_err): {std_err}")
# Out:
# Pendiente (slope): 0.33437045310825675
# Intersección (intercept): -16.775825554463808
# Coeficiente de correlación (r_value): 0.9394077833002425
# Error estándar (std_err): 0.002211174812544082

# %%
# Generar los valores de y de acuerdo con la recta de regresión
y_pred = slope * x + intercept

# %%
# Graficar los datos y la recta de mejor ajuste
plt.figure(figsize=(12, 8))
plt.scatter(x, y, color='blue') #edgecolor='k')#, alpha=0.7, s=100, #label='Datos')
plt.plot(x, y_pred, color='yellow', linewidth=2) #linestyle='--', #label=f'Recta de mejor ajuste: y = {slope:.2f}x + {intercept:.2f}')
plt.xlabel('avganncount')#, fontsize=14)
plt.ylabel('avgdeathsperyear')#, fontsize=14)
plt.title('Recta de regresión lineal')#, fontsize=16)
#plt.legend(fontsize=12)
#plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Seleccionar las características de dependencia lineal
features_depend_lineal2 = ['pctprivatecoverage', 'povertypercent']

# %%
# Filtrar las características dependientes lineales
ft_depend_lineales2 = df_selec[features_depend_lineal2]
corr = ft_depend_lineales2.corr()
print(corr)
# Out:
#                     pctprivatecoverage  povertypercent
# pctprivatecoverage            1.000000       -0.822534
# povertypercent               -0.822534        1.000000

# %%
# Guardar las características dependientes lineales en un nuevo archivo CSV
df = pd.DataFrame(ft_depend_lineales2)
df.to_csv("depend_lineales2.csv", index=False)

# %%
# Cargar los datos desde el archivo CSV
df = pd.read_csv('depend_lineales2.csv')

# %%
# Asignar las columnas correspondientes
x = df['pctprivatecoverage']
y = df['povertypercent']

# %%
# Calcular la recta de mejor ajuste (regresión lineal)
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# %%
# Mostrar los resultados de la regresión
print(f"Pendiente (slope): {slope}")
print(f"Intersección (intercept): {intercept}")
print(f"Coeficiente de correlación (r_value): {r_value}")
print(f"Error estándar (std_err): {std_err}")
# Out:
# Pendiente (slope): -0.49513155447559654
# Intersección (intercept): 48.742336380486535
# Coeficiente de correlación (r_value): -0.8225342922711801
# Error estándar (std_err): 0.00620394615603114

# %%
# Generar los valores de y de acuerdo con la recta de regresión
y_pred = slope * x + intercept

# %%
# Graficar los datos y la recta de mejor ajuste
plt.figure(figsize=(12, 8))
plt.scatter(x, y, color='blue') #edgecolor='k')#, alpha=0.7, s=100, #label='Datos')
plt.plot(x, y_pred, color='yellow', linewidth=2) #linestyle='--', #label=f'Recta de mejor ajuste: y = {slope:.2f}x + {intercept:.2f}')
plt.xlabel('pctprivatecoverage')#, fontsize=14)
plt.ylabel('povertypercent')#, fontsize=14)
plt.title('Recta de regresión lineal')#, fontsize=16)
#plt.legend(fontsize=12)
#plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Seleccionar las características de dependencia lineal
features_depend_lineal3 = ['incidencerate', 'medincome']

# %%
# Filtrar las características dependientes lineales
ft_depend_lineales3 = df_selec[features_depend_lineal3]
corr = ft_depend_lineales3.corr()
print(corr)
# Out:
#                incidencerate  medincome
# incidencerate       1.000000  -0.001036
# medincome          -0.001036   1.000000

# %%
# Guardar las características dependientes lineales en un nuevo archivo CSV
df = pd.DataFrame(ft_depend_lineales3)
df.to_csv("depend_lineales3.csv", index=False)

# %%
# Cargar los datos desde el archivo CSV
df = pd.read_csv('depend_lineales3.csv')

# %%
# Asignar las columnas correspondientes
x = df['incidencerate']
y = df['medincome']

# %%
# Calcular la recta de mejor ajuste (regresión lineal)
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# %%
# Mostrar los resultados de la regresión
print(f"Pendiente : {slope}")
print(f"Intersección : {intercept}")
print(f"Coeficiente de correlación : {r_value}")
print(f"Error estándar : {std_err}")
# Out:
# Pendiente : -0.22865838635421407
# Intersección : 47165.78228812313
# Coeficiente de correlación : -0.001036185629497317
# Error estándar : 3.9990394443621424

# %%
# Generar los valores de y de acuerdo con la recta de regresión
y_pred = slope * x + intercept

# %%
# Graficar los datos y la recta de mejor ajuste
plt.figure(figsize=(12, 8))
plt.scatter(x, y, color='blue') #edgecolor='k')#, alpha=0.7, s=100, #label='Datos')
plt.plot(x, y_pred, color='yellow', linewidth=2) #linestyle='--', #label=f'Recta de mejor ajuste: y = {slope:.2f}x + {intercept:.2f}')
plt.xlabel('incidencerate')#, fontsize=14)
plt.ylabel('medincome')#, fontsize=14)
plt.title('Recta de regresión lineal')#, fontsize=16)
#plt.legend(fontsize=12)
#plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
#depend_linear = []
#for i in range(len(features)):
 #   for j in range(i+1, len(features)):
  #      feature1 = features[i]
   #     feature2 = features[j]
    #    slope, intercept, r_value, p_value, std_err = linregress(df_selec[feature1], df_selec[feature2])
     #   if abs(r_value) > 0.7:  # Considerar relaciones lineales fuertes con r > 0.7
      #      depend_linear.append((feature1, feature2, slope, intercept, r_value))

#print("\nDependencias lineales (con r > 0,7):")
#for dep in depend_linear:
 #   print(f"{dep} vs {dep}: Pendiente = {dep}, Intersección = {dep}, r = {dep}")

# %%
# Encontrar dependencias lineales y calcular la ecuación de la recta
#depend_linear = []
#for i in range(len(features)):
 #   for j in range(i+1, len(features)):
  #      feature1 = features[i]
   #     feature2 = features[j]
    #    slope, intercept, r_value, p_value, std_err = linregress(df_selec[feature1], df_selec[feature2])
     #   if abs(r_value) > 0.7:  # Considerar relaciones lineales fuertes con r > 0.7
      #      depend_linear.append((feature1, feature2, slope, intercept, r_value))
            
            # Graficar la relación lineal
       #     plt.figure(figsize=(10, 6))
        #    sns.scatterplot(x=df_selec[feature1], y=df_selec[feature2])
         #   plt.plot(df_selec[feature1], slope * df_selec[feature1] + intercept, color='red')
          #  plt.title(f'{feature1} vs {feature2}\nPendiente: {slope:.4f}, Intersección: {intercept:.4f}, r: {r_value:.4f}')
           # plt.xlabel(feature1)
            #plt.ylabel(feature2)
            #plt.show()
            
#print("\nDependencias lineales (con r > 0,7):")
#for dep in depend_linear:
 #   print(f"{dep} vs {dep}: Pendiente = {dep}, Intersección = {dep}, r = {dep}")
