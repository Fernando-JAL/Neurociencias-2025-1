# %% [markdown]
# # Ejercicio

# %% [markdown]
# ### Generar un número aleatorio entero en el rango [-3, 3] con seed=5002

# %%
import random

random.seed(5002)

numero_aleatorio = random.randint(-3, 3)

print('Número aleatorio generado:', numero_aleatorio)
# Out:
# Número aleatorio generado: 2

# %% [markdown]
# ### Generar un número aleatorio flotante en el rango [-10, 10] con seed=5002

# %%
numero_aleatorio_flotante = random.uniform(-10, 10)

print("Número aleatorio flotante generado:", numero_aleatorio_flotante)
# Out:
# Número aleatorio flotante generado: 9.787818529556397

# %% [markdown]
# ### Genera un array de 1000 números con distribución normal, con mu= ej1, y sigma= ej2

# %%
import numpy as np

mu = 5
sigma = 2

array_normal = np.random.normal(mu, sigma, 1000)

print("Primeros 10 números generados:", array_normal[:10])
# Out:
# Primeros 10 números generados: [6.03958699 5.58206571 3.47185649 5.82579814 6.84640298 6.60974695
#  6.00221698 2.71397361 7.86910387 3.17112649]

# %% [markdown]
# ### Plotear la distribución de los 1000 números

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 1

array_normal = np.random.normal(mu, sigma, 1000)

plt.figure(figsize=(10, 6))
plt.hist(array_normal, bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)
plt.plot(x, p, 'k', linewidth=2)

plt.title('Distribución Normal')
plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Calcular el valor de 1sigma, 2sigma, 3sigma

# %%
mu = 0
sigma = 1

one_sigma = (mu - sigma, mu + sigma)
two_sigma = (mu - 2 * sigma, mu + 2 * sigma)
three_sigma = (mu - 3 * sigma, mu + 3 * sigma)

print("1σ: ", one_sigma)
print("2σ: ", two_sigma)
print("3σ: ", three_sigma)
# Out:
# 1σ:  (-1, 1)
# 2σ:  (-2, 2)
# 3σ:  (-3, 3)

# %% [markdown]
# ### Calcular el porcentaje de números que están en el rango [-1sigma, 1sigma]

# %%
mu = 0
sigma = 1

array_normal = np.random.normal(mu, sigma, 1000)

lower_limit = mu - sigma
upper_limit = mu + sigma

count_in_range = np.sum((array_normal >= lower_limit) & (array_normal <= upper_limit))

percentage_in_range = (count_in_range / len(array_normal)) * 100

print("Porcentaje de números en el rango [-1sigma, 1sigma]:", percentage_in_range)
# Out:
# Porcentaje de números en el rango [-1sigma, 1sigma]: 66.2

# %% [markdown]
# ### Calcular el porcentaje de números que están en el rango [-2sigma, 2sigma]

# %%
mu = 0
sigma = 1

array_normal = np.random.normal(mu, sigma, 1000)

lower_limit = mu - 2 *sigma
upper_limit = mu + 2 *sigma

count_in_range = np.sum((array_normal >= lower_limit) & (array_normal <= upper_limit))

percentage_in_range = (count_in_range / len(array_normal)) * 100

print("Porcentaje de números en el rango [-2sigma, 2sigma]:", percentage_in_range)
# Out:
# Porcentaje de números en el rango [-2sigma, 2sigma]: 94.89999999999999

# %% [markdown]
# ### Calcular el porcentaje de números que están en el rango [-3sigma, 3sigma]

# %%
mu = 0
sigma = 1

array_normal = np.random.normal(mu, sigma, 1000)

lower_limit = mu - 3 *sigma
upper_limit = mu + 3 *sigma

count_in_range = np.sum((array_normal >= lower_limit) & (array_normal <= upper_limit))

percentage_in_range = (count_in_range / len(array_normal)) * 100

print("Porcentaje de números en el rango [-3sigma, 3sigma]:", percentage_in_range)
# Out:
# Porcentaje de números en el rango [-3sigma, 3sigma]: 99.8

# %% [markdown]
# ### Crear una función que reciba un entero (mu), un flotante (sigma) y un entero (total de números) y: genere array de números con distribución normal, con mu, y sigma. Plotee la distribución, calcule los sigmas, calcule el porcentaje de números que están en los rangos de +-1sigmam +-2sigma, +-3sigma

# %%
def analizar_distribucion(mu, sigma, total):
  array_normal = np.random.normal(mu, sigma, total)

  plt.figure(figsize=(10, 6))
  plt.hist(array_normal, bins=30, density=True, alpha=0.6, color='g')

  xmin, xmax =plt.xlim()
  x = np.linspace(xmin, xmax, 100)
  p = (1 / (sigma * np.sqrt(2 *np.pi))) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)
  plt.plot(x, p, 'k', linewidth=2)
  plt.title(f'Distribución normal (mu={mu}, sigma={sigma})')
  plt.xlabel('Valores')
  plt.ylabel('Densidad de Probabilidad')
  plt.grid(True)
  plt.show()

rangos = [1, 2, 3]
porcentajes = {}
total = 1000
for r in rangos:
  lower_limit = mu - r * sigma
  upper_limit = mu + r * sigma
  count_in_range = np.sum((array_normal >= lower_limit) & (array_normal <= upper_limit))
  porcentajes[f"{r}sigma"] = (count_in_range / total) * 100

for r, porcentaje in porcentajes.items():
  print(f"Porcentajes de números en el rango ±{r}: {porcentaje:.2f}%")

analizar_distribucion(mu=0, sigma=1, total=total)
# Out:
# Porcentajes de números en el rango ±1sigma: 69.30%
# Porcentajes de números en el rango ±2sigma: 96.20%
# Porcentajes de números en el rango ±3sigma: 99.80%

# %% [markdown]
# ### Usar la función anterior con los valores (0, 1., 1000), (3, 5, 5000), (-3, 3, 10000)

# %%
print("Caso (0, 1.0, 1000):")
analizar_distribucion(mu=0, sigma=1.0, total=1000)

print("\nCaso (3, 5, 5000):")
analizar_distribucion(mu=3, sigma=5, total=5000)

print("\nCaso (-3, 3, 10000):")
analizar_distribucion(mu=3, sigma=3, total=10000)
# Out:
# Caso (0, 1.0, 1000):
# Caso (3, 5, 5000):
# Caso (-3, 3, 10000):
