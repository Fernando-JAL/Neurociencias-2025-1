# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0  0.357680  0.960801 -0.393058 -0.382288 -1.631224
# 1  0.430900 -0.521982 -0.752806 -0.847565 -1.194688
# 2  1.494486  0.028987 -0.722868 -0.774810  0.623758
# 3  0.947887 -0.670685  0.618436  1.985957  1.159892
# 4 -0.735694  0.244440 -0.671253  0.834914 -0.014603
# 5 -0.261273  0.245755 -0.247738  0.278253 -0.618292
# 6 -0.182352  0.327728 -0.364101  1.738908  0.385393
# 7 -0.270333  0.946570 -0.982107 -1.061977  1.806057
# 8 -0.582724  0.911905  0.026370  0.765394  1.069054
# 9  0.111027  0.044190  0.908044 -0.522109 -0.150065

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv(r'C:\Users\OMEN CI7\Documents\repository\Neurociencias-2025-1\datos_new.csv', index=False, sep=';')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv', sep=';')

df
# Out:
#           A         L         U         M         N
# 0  0.423316  1.128516  0.143195 -1.412365  0.948779
# 1  0.988903 -1.822290  0.889723 -0.996754 -0.951893
# 2 -0.062858 -0.587966 -0.543627 -0.384588  1.262243
# 3  2.089130 -0.500271 -1.090680 -0.335303 -1.062144
# 4 -1.081333 -1.590270  1.355750 -0.348654 -0.465290
# 5  0.013306  0.176789 -1.237786 -0.411910  2.284914
# 6 -0.306311  2.023690  0.912722  0.474339  0.656709
# 7  0.562535  0.028841 -1.126961  0.246404  1.175491
# 8 -0.652287  0.982229  1.177281 -0.735292  2.597402
# 9  0.694994 -0.541511 -0.066688  0.335089  0.345040

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df
# Out:
#           A         L         U         M         N
# 0  0.423316  1.128516  0.143195 -1.412365  0.948779
# 1  0.988903 -1.822290  0.889723 -0.996754 -0.951893
# 2 -0.062858 -0.587966 -0.543627 -0.384588  1.262243
# 3  2.089130 -0.500271 -1.090680 -0.335303 -1.062144
# 4 -1.081333 -1.590270  1.355750 -0.348654 -0.465290
# 5  0.013306  0.176789 -1.237786 -0.411910  2.284914
# 6 -0.306311  2.023690  0.912722  0.474339  0.656709
# 7  0.562535  0.028841 -1.126961  0.246404  1.175491
# 8 -0.652287  0.982229  1.177281 -0.735292  2.597402
# 9  0.694994 -0.541511 -0.066688  0.335089  0.345040

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df_json = pd.read_json('datos.json')

df_json
# Out:
#           A         L         U         M         N
# 0  0.423316  1.128516  0.143195 -1.412365  0.948779
# 1  0.988903 -1.822290  0.889723 -0.996754 -0.951893
# 2 -0.062858 -0.587966 -0.543627 -0.384588  1.262243
# 3  2.089130 -0.500271 -1.090680 -0.335303 -1.062144
# 4 -1.081333 -1.590270  1.355750 -0.348654 -0.465290
# 5  0.013306  0.176789 -1.237786 -0.411910  2.284914
# 6 -0.306311  2.023690  0.912722  0.474339  0.656709
# 7  0.562535  0.028841 -1.126961  0.246404  1.175491
# 8 -0.652287  0.982229  1.177281 -0.735292  2.597402
# 9  0.694994 -0.541511 -0.066688  0.335089  0.345040

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl

# %% [markdown]
# ### Guardar a Excel

# %%
df
# Out:
#           A         L         U         M         N
# 0  0.423316  1.128516  0.143195 -1.412365  0.948779
# 1  0.988903 -1.822290  0.889723 -0.996754 -0.951893
# 2 -0.062858 -0.587966 -0.543627 -0.384588  1.262243
# 3  2.089130 -0.500271 -1.090680 -0.335303 -1.062144
# 4 -1.081333 -1.590270  1.355750 -0.348654 -0.465290
# 5  0.013306  0.176789 -1.237786 -0.411910  2.284914
# 6 -0.306311  2.023690  0.912722  0.474339  0.656709
# 7  0.562535  0.028841 -1.126961  0.246404  1.175491
# 8 -0.652287  0.982229  1.177281 -0.735292  2.597402
# 9  0.694994 -0.541511 -0.066688  0.335089  0.345040

# %%
df.to_excel('datos.xlsx', sheet_name='hoja1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='hoja1')

df
# Out:
#           A         L         U         M         N
# 0  0.423316  1.128516  0.143195 -1.412365  0.948779
# 1  0.988903 -1.822290  0.889723 -0.996754 -0.951893
# 2 -0.062858 -0.587966 -0.543627 -0.384588  1.262243
# 3  2.089130 -0.500271 -1.090680 -0.335303 -1.062144
# 4 -1.081333 -1.590270  1.355750 -0.348654 -0.465290
# 5  0.013306  0.176789 -1.237786 -0.411910  2.284914
# 6 -0.306311  2.023690  0.912722  0.474339  0.656709
# 7  0.562535  0.028841 -1.126961  0.246404  1.175491
# 8 -0.652287  0.982229  1.177281 -0.735292  2.597402
# 9  0.694994 -0.541511 -0.066688  0.335089  0.345040

# %% [markdown]
# ## HTML
#
# Podemos extraer información directamente desde tablas de páginas web a partir de la URL.
#
# Esto se consigue haciendo web scrapping con los módulos `lxml` y `BeautifulSoup4`, por lo que necesitamos instalarlos:
#
#     pip install lxml BeautifulSoup4

# %%
# !pip install lxml BeautifulSoup4

# %% [markdown]
# Una vez instalado `lxml` y `BeautifulSoup4` reiniciamos el kernel (botón girando al lado de stop) y ya estaremos listos:

# %%
# Realizamos un scrapping de una tabla de la wikipedia
df = pd.read_html('https://web.archive.org/web/20220717170349/https://en.wikipedia.org/wiki/List_of_countries_by_past_fertility_rate')

# %%
len(df)
# Out:
# 6

# %%
df[1].head()
# Out:
#                                                   0          1          2   \
# 0  Fertility rate per woman Country/dependent ter...        NaN        NaN
# 1                        Country/dependent territory  1950–1955  1955–1960
# 2                                        Afghanistan       7.45       7.45
# 3                                            Albania       6.23       6.55
# 4                                            Algeria       7.28       7.38
#
#           3          4          5          6          7          8   \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  1960–1965  1965–1970  1970–1975  1975–1980  1980–1985  1985–1990
# 2       7.45       7.45       7.45       7.45       7.45       7.45
# 3       6.23       5.26       4.60       3.90       3.41       3.15
# 4       7.65       7.65       7.57       7.18       6.32       5.30
#
#           9          10         11         12         13
# 0        NaN        NaN        NaN        NaN        NaN
# 1  1990–1995  1995–2000  2000–2005  2005–2010  2010–2015
# 2       7.48       7.65       7.18       6.37       5.26
# 3       2.79       2.38       1.95       1.64       1.71
# 4       4.12       2.88       2.38       2.72       2.96

# %% [markdown]
# Si se encuentra más de una tabla (como en el caso del ejemplo), podemos hacer referencia al primero a través del índice:

# %%
df[2]
# Out:
#     Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                   Afghanistan       7.45       7.45       7.45       7.45
# 1                       Albania       6.23       6.55       6.23       5.26
# 2                       Algeria       7.28       7.38       7.65       7.65
# 3                        Angola       7.30       7.35       7.60       7.60
# 4           Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                          ...        ...        ...        ...        ...
# 197           Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                       Yemen       7.35       7.40       7.60       7.80
# 199                      Zambia       6.70       6.95       7.25       7.30
# 200                    Zimbabwe       6.80       7.00       7.30       7.40
# 201                       World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Podemos hacer un poco de limpieza y dejar los datos presentables:

# %%
# Guardamos el dataframe
fertility_rate = df[2]

fertility_rate.head()
# Out:
#   Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                 Afghanistan       7.45       7.45       7.45       7.45
# 1                     Albania       6.23       6.55       6.23       5.26
# 2                     Algeria       7.28       7.38       7.65       7.65
# 3                      Angola       7.30       7.35       7.60       7.60
# 4         Antigua and Barbuda       4.50       4.50       4.30       4.00
#
#    1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0       7.45       7.45       7.45       7.45       7.48       7.65
# 1       4.60       3.90       3.41       3.15       2.79       2.38
# 2       7.57       7.18       6.32       5.30       4.12       2.88
# 3       7.60       7.60       7.40       7.35       7.10       6.75
# 4       3.26       2.24       2.14       2.07       2.09       2.31
#
#    2000–2005  2005–2010  2010–2015
# 0       7.18       6.37       5.26
# 1       1.95       1.64       1.71
# 2       2.38       2.72       2.96
# 3       6.55       6.35       5.95
# 4       2.27       2.17       2.10

# %%
# Renombramos la primera columna para que sea más fácil consultarla
fertility_rate.rename(columns = {'Country/dependent territory':'Country'}, inplace=True)

fertility_rate
# Out:
#                  Country  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0            Afghanistan       7.45       7.45       7.45       7.45
# 1                Albania       6.23       6.55       6.23       5.26
# 2                Algeria       7.28       7.38       7.65       7.65
# 3                 Angola       7.30       7.35       7.60       7.60
# 4    Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                   ...        ...        ...        ...        ...
# 197    Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                Yemen       7.35       7.40       7.60       7.80
# 199               Zambia       6.70       6.95       7.25       7.30
# 200             Zimbabwe       6.80       7.00       7.30       7.40
# 201                World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Ahora podemos realizar consultas cómodamente:

# %%
# Índice de natalidad por país entre los años 2010-2015
fertility_rate[["Country", "2010–2015"]]
# Out:
#                  Country  2010–2015
# 0            Afghanistan       5.26
# 1                Albania       1.71
# 2                Algeria       2.96
# 3                 Angola       5.95
# 4    Antigua and Barbuda       2.10
# ..                   ...        ...
# 197    Western Sahara[7]       2.60
# 198                Yemen       4.40
# 199               Zambia       5.20
# 200             Zimbabwe       4.00
# 201                World       2.52
#
# [202 rows x 2 columns]

# %%
# Misma consulta aplicando el styler para esconder la primera columna
fertility_rate[["Country", "2010–2015"]].head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_07cd6">
#   <thead>
#     <tr>
#       <th id="T_07cd6_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_07cd6_level0_col1" class="col_heading level0 col1" >2010–2015</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_07cd6_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_07cd6_row0_col1" class="data row0 col1" >5.260000</td>
#     </tr>
#     <tr>
#       <td id="T_07cd6_row1_col0" class="data row1 col0" >Albania</td>
#       <td id="T_07cd6_row1_col1" class="data row1 col1" >1.710000</td>
#     </tr>
#     <tr>
#       <td id="T_07cd6_row2_col0" class="data row2 col0" >Algeria</td>
#       <td id="T_07cd6_row2_col1" class="data row2 col1" >2.960000</td>
#     </tr>
#     <tr>
#       <td id="T_07cd6_row3_col0" class="data row3 col0" >Angola</td>
#       <td id="T_07cd6_row3_col1" class="data row3 col1" >5.950000</td>
#     </tr>
#     <tr>
#       <td id="T_07cd6_row4_col0" class="data row4 col0" >Antigua and Barbuda</td>
#       <td id="T_07cd6_row4_col1" class="data row4 col1" >2.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más a menos (primeros resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6125">
#   <thead>
#     <tr>
#       <th id="T_e6125_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_e6125_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e6125_row0_col0" class="data row0 col0" >Yemen</td>
#       <td id="T_e6125_row0_col1" class="data row0 col1" >8.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e6125_row1_col0" class="data row1 col0" >Oman</td>
#       <td id="T_e6125_row1_col1" class="data row1 col1" >7.850000</td>
#     </tr>
#     <tr>
#       <td id="T_e6125_row2_col0" class="data row2 col0" >Rwanda</td>
#       <td id="T_e6125_row2_col1" class="data row2 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e6125_row3_col0" class="data row3 col0" >Niger</td>
#       <td id="T_e6125_row3_col1" class="data row3 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_e6125_row4_col0" class="data row4 col0" >Burundi</td>
#       <td id="T_e6125_row4_col1" class="data row4 col1" >7.550000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más o menos (últimos resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).tail().style.hide(axis=0)

# %%
# Vamos a transformar todas las columnas desde la segunda hasta la última a valores númericos
fertility_rate = fertility_rate[1:][:].apply(pd.to_numeric, errors='coerce')

# %%
# Ahora podemos consultar la media del índice de natalidad para cada año
fertility_rate.mean()[1:]

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# C:\Users\OMEN CI7\AppData\Local\Temp\ipykernel_15904\1476254313.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# <AxesSubplot:xlabel='Períodos', ylabel='Media de natalidad mundial'>

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
