# %%
import scipy.io

# %%
path = r"C:\Users\OMEN CI7\Documents\repository\Neurociencias-2025-1\BCT\BCT\2019_03_03_BCT\data_and_demos\Coactivation_matrix.mat"

mat_json = scipy.io.loadmat(path)
mat_json
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNX86, Created on: Wed Dec 25 01:14:03 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Coactivation_matrix': array([[0.        , 0.16071429, 0.11148649, ..., 0.        , 0.05045872,
#          0.1011236 ],
#         [0.16071429, 0.        , 0.06825939, ..., 0.        , 0.        ,
#          0.06923077],
#         [0.11148649, 0.06825939, 0.        , ..., 0.03412969, 0.        ,
#          0.        ],
#         ...,
#         [0.        , 0.        , 0.03412969, ..., 0.        , 0.        ,
#          0.        ],
#         [0.05045872, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.09777778],
#         [0.1011236 , 0.06923077, 0.        , ..., 0.        , 0.09777778,
#          0.        ]]),
#  'Coord': array([[ 7.24363636, 37.01090909,  9.42545455],
#         [ 7.98653199, 46.22222222, 15.60942761],
#         [ 7.55725191, 33.83206107, 23.51145038],
#         ...,
# ...

# %%
cijall = mat_json['CIJall']
cijctx = mat_json['CIJctx']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.heatmap(cijall, cmap='PiYG')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.heatmap(cijctx, cmap='PiYG')
plt.show()

# %%
filtered = cijctx > 1.5
fig = plt.figure(figsize=(8, 8))
ax = sns.heatmap(filtered, cmap='PiYG')
plt.show()
