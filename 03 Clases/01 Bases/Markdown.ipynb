# %% [markdown]
# # Para modificar una celda a formato Markdown o Code se antepone Esc
# Formato Code Esc + y
#
# Formato Markdown Esc + m

# %% [markdown]
# # Titulo
#
# ## Subtitulo
#
# ### Sección
#
# ##### Subsección
#
# ##### Otra cosa
#
# Texto normal
#
# **Texto negritas** o __texto negritas__
#
# *Texto cursiva* o _texto cursiva_
#
# 3
#
# $3$
#
# $\sum_{i = 1}^{n}{i^2}$
#
# $\int_0^\infty{x^2dx}$

# %% [markdown]
# Bullets:
# - linea1
#     - line2
#     - line3
# - linea3
#     - linea_prev
#         - linea 4
#             - linea 5
#
# Listados:
# 1. linea1
# 1. linea2
#     1. linea3
#         1. linea4
#             1. linea5
#     1. linea6

# %%
# este es un comentario para código

# %%
"""
Description of the script. This script is used to describe how to use Markdowns
"""
# Out:
# '\nDescription of the script. This script is used to describe how to use Markdowns\n'

# %%
# Comments

# %% [markdown]
# ![kiddo.jpeg](attachment:kiddo.jpeg)
